# %% [markdown]
# # Debut

# %%
from jax import random, jit, vmap
import os
path = os.getcwd()
print("Old path:", path)
path = (path.split('/'))
path = path[:path.index("ABC-SBI")+1]
path = '/'.join(path)
print("New path:", path)
os.chdir(path)
from functions.training import train_loop
import jax.numpy as jnp
import time
import pickle 
import lzma
from jax.scipy.stats import norm, gaussian_kde
from scipy.stats import ranksums
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats as stats
from sbibm.metrics import c2st
import torch
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split

from functions.simulation import logratio_batch_z, logratio_z, NRE_posterior_pdf, NRE_corrected_posterior_pdf, find_grid_explorative, NRE_corrected_posterior_sample, NRE_posterior_sample
from functions.metrics import c2stest, evaluate_metrics, ranksumstest_stat, ranksumstest_pvalue
from functions.plots import plot_metric, plot_posterior_comparison
from functions.save import create_csv_for_a_dataset
import pandas as pd

@jit
def prior_simulator(key):
    return random.normal(key, (1,))*SIGMA0 + MU0

@jit
def data_simulator(key, theta):
    return (random.normal(key, (N_DATA,))*SIGMA + theta).astype(float)

@jit
def discrepancy(y, y_true):
    return (jnp.mean(y) - jnp.mean(y_true))**2

def true_post(z):
    mu_post = (MU0*SIGMA**2 + SIGMA0**2 * np.sum(z))/(SIGMA0**2*len(z) + SIGMA**2)
    sigma2_post = 1/(1/SIGMA0**2 + len(z)/SIGMA**2)
    return stats.norm(loc = mu_post, scale = np.sqrt(sigma2_post))
# Out:
# Old path: /Users/antoineluciano/Documents/Recherche/ABC-SBI/examples/Gauss-Gauss/Gauss_Gauss_1D_known_sigma
# New path: /Users/antoineluciano/Documents/Recherche/ABC-SBI
# /Users/antoineluciano/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/torch/utils/_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(

# %%
def true_post(z):
    mu_post = (MU0*SIGMA**2 + SIGMA0**2 * np.sum(z))/(SIGMA0**2*len(z) + SIGMA**2)
    sigma2_post = 1/(1/SIGMA0**2 + len(z)/SIGMA**2)
    return stats.norm(loc = mu_post, scale = np.sqrt(sigma2_post))

def true_posterior_sample(key, TRUE_DATA, N_SAMPLE):
    mu_post = (MU0*SIGMA**2 + SIGMA0**2 * jnp.sum(TRUE_DATA))/(SIGMA0**2*len(TRUE_DATA) + SIGMA**2)
    sigma2_post = 1/(1/SIGMA0**2 + len(TRUE_DATA)/SIGMA**2)
    return random.normal(key, (N_SAMPLE,))*jnp.sqrt(sigma2_post)+ mu_post


def true_posterior_pdf(theta, TRUE_DATA):
    mu_post = (MU0*SIGMA**2 + SIGMA0**2 * jnp.sum(TRUE_DATA))/(SIGMA0**2*len(TRUE_DATA) + SIGMA**2)
    sigma2_post = 1/(1/SIGMA0**2 + len(TRUE_DATA)/SIGMA**2)
    return stats.norm(loc = mu_post, scale = jnp.sqrt(sigma2_post)).pdf(theta)

    

def true_ratio_z(mus, z, prior, posterior):
    return posterior(z).pdf(mus)/prior.pdf(mus)

def true_decision_z(mus, z, prior, posterior):
    return 1/(1+1/true_ratio_z(mus, z, prior, posterior))

def true_pseudo_ratio_z(mus, z, bar_xobs, epsilon, prior, posterior):
    pseudo = true_pseudo_post(mus, bar_xobs, epsilon, prior)
    Z_pseudo = np.trapz(pseudo, mus)
    return posterior(z).pdf(mus)/pseudo*Z_pseudo

def true_pseudo_decision_z(mus, z, bar_xobs, epsilon, prior, posterior):
    return 1/(1+1/true_pseudo_ratio_z(mus, z, bar_xobs, epsilon, prior, posterior))

def true_pseudo_post(mus, bar_xobs, epsilon, prior):
    return prior.pdf(mus)*(norm.cdf(bar_xobs+np.sqrt(epsilon), loc = mus, scale = SIGMA/np.sqrt(N_DATA)) - norm.cdf(bar_xobs-np.sqrt(epsilon), loc = mus, scale = SIGMA/np.sqrt(N_DATA)))

def true_pseudo_decision_z(mus, z, bar_xobs, epsilon, prior, posterior):
    return 1/(1+1/true_pseudo_ratio_z(mus, z, bar_xobs, epsilon, prior, posterior))

def decision_z(params, mus, z):
    return 1/(1+jnp.exp(-logratio_z(params, mus, z)))
def decision_batch_z(params, mus, z):
    return 1/(1+jnp.exp(-logratio_batch_z(params, mus, z)))

def ABC_gauss_single(key, true_data, epsilon):
    key, key_xbar = random.split(key)
    xbar = random.truncated_normal(key_xbar, lower = (jnp.mean(true_data)-jnp.sqrt(epsilon)-MU0)/jnp.sqrt(SIGMA0**2+SIGMA**2/len(true_data)), upper = (jnp.mean(true_data)+jnp.sqrt(epsilon)-MU0)/jnp.sqrt(SIGMA0**2+SIGMA**2/len(true_data)))*jnp.sqrt(SIGMA0**2+SIGMA**2/len(true_data)) + MU0
    dist = (jnp.mean(true_data)-xbar)**2
    key, key_z = random.split(key)
    z = random.normal(key_z, (len(true_data),))*SIGMA
    z = z-jnp.mean(z)+xbar
    key, key_mu = random.split(key)
    mu = random.normal(key_mu, (1,))*SIGMA/jnp.sqrt(len(true_data)) + xbar
    return z, mu, dist


def ABC_gauss(key, true_data, epsilon, N_ABC):
    keys = random.split(key, N_ABC+1)
    zs, mus, dists = vmap(jit(ABC_gauss_single), (0, None, None))(keys[1:], true_data, epsilon)
    return zs, mus, dists, keys[0]

def get_epsilon_star_gauss(key, acceptance_rate, n_points, prior_simulator, data_simulator, discrepancy, true_data, quantile_rate = .9, epsilon = jnp.inf, return_accept = False):
    new_epsilon = epsilon
    accept = 1.
    
    datas, thetas, dists, key = ABC_gauss(key, true_data, epsilon, n_points)
    if epsilon == jnp.inf:
        print("Distances: min = ", jnp.min(dists), "max = ", jnp.max(dists), "mean = ", jnp.mean(dists), "std = ", jnp.std(dists))
    while accept > acceptance_rate:
        epsilon = new_epsilon
        new_epsilon = float(jnp.quantile(dists, quantile_rate))
        datas, thetas, dists, key = ABC_gauss(key, true_data, new_epsilon, n_points)
        key, subkey = random.split(key)
        keys_pred = random.split(subkey, n_points)
        datas_pred = vmap(data_simulator, in_axes=(0, 0))(keys_pred, thetas)
        new_dists = vmap(discrepancy, in_axes=(0, None))(datas_pred, true_data)
        accept = jnp.mean(new_dists < new_epsilon)
        epsilon = new_epsilon
        print("epsilon: ", epsilon, "acceptance rate: ", accept)
    if return_accept: 
        return epsilon, accept, key
    return epsilon, key

def get_dataset_gauss(key, n_points, prior_simulator, data_simulator, discrepancy, epsilon, true_data):
    n_points = n_points//2
    zs, thetas, _, key = ABC_gauss(key, true_data, epsilon, n_points)
    key, key_perm = random.split(key)
    thetas_prime = thetas[random.permutation(key_perm, jnp.arange(n_points))]
    zs = jnp.concatenate([zs, zs], axis=0)
    thetas = jnp.concatenate([thetas, thetas_prime], axis=0)
    ys = jnp.append(jnp.zeros(n_points), jnp.ones(n_points)).astype(int)
    Xs = jnp.concatenate([thetas, zs], axis=1)
    return Xs, ys, key

# %% [markdown]
# The standard NRE output is the ratio:
# $$\hat r(x\mid \theta) \approx r(x\mid \theta) = \frac{f(x\mid\theta)}{p(x)} = \frac{\pi(\theta\mid x)}{\pi(\theta)}$$
#
# The posterior approximation is then
# $$\hat \pi(\theta\mid x) \propto \pi(\theta) \cdot\hat r(x\mid \theta)$$
#
# Here we train the NRE classifier with datas from the ABC joint pseudo posterior $\pi_\epsilon(\theta,x\mid x_o)$ with $\epsilon \in ] 0 , + \infty [$.
#
# The ABC-NRE output is then:
# $$\hat r_\epsilon(x\mid \theta, x_o) \approx r_\epsilon(x\mid \theta, x_o) =  \frac{\pi(\theta\mid x)}{\pi_\epsilon(\theta\mid x_o)}$$
#
# and the posterior approximation becomes :
#
# $$\hat \pi(\theta\mid x, x_o) \propto \hat \pi_\epsilon(\theta\mid x_o) \cdot \hat r_\epsilon(x\mid \theta, x_o)$$
#
# where $ \hat \pi_\epsilon(\theta\mid x_o) $ is a KDE approximation of the ABC pseudo posterior that plays the role of the ABC correction.
#
#
# Here we compare:
# - the ABC-NRE approximation with the KDE correction: $\hat \pi(\theta\mid x, x_o) \propto \hat \pi_\epsilon(\theta\mid x_o) \cdot \hat r_\epsilon(x\mid \theta, x_o)$.
# - the ABC-NRE approximation without the KDE correction: $\hat \pi(\theta\mid x, x_o) \propto \pi(\theta) \cdot r_\epsilon(x\mid \theta, x_o)$.
# - the ABC pseudo posterior: $\pi_\epsilon(\theta\mid x_o)$
# - the true posterior: $\pi(\theta\mid x_o)$.
#
# Here we consider the Gaussian toy model
# $$\mu \sim \mathcal N(0, 10^2) \quad x = (x_1, \cdots, x_n) \sim \mathcal N(\mu, 1)$$
#
# Even with $n = 10$, we remark that $r_\epsilon (x \mid \theta, x_o) >> \pi_\epsilon(\theta\mid x_o) \approx \pi(\theta)$ so there is no the correction does not change the posterior approximation.
#
# When $\epsilon$ is too small, $r_\epsilon(x\mid \theta, x_o) \propto 1$ and $\pi_\epsilon(\theta\mid x_o) \approx \pi(\theta\mid x_o)$. The NRE approximation without the correction is then the prior and becomes close to the posterior with the ABC correction.

# %% [markdown]
# # Data simulation ($x_o$)

# %%
key = random.PRNGKey(0)
SIGMA0 = 20.
MU0 = 0.
SIGMA = 1.
TRUE_MU = 2.*SIGMA0
N_DATA = 5
MODEL_ARGS = [SIGMA]
PRIOR_ARGS = [MU0, SIGMA0]

key, subkey = random.split(key)
TRUE_DATA = random.normal(subkey, (N_DATA,))*SIGMA + TRUE_MU

PRIOR_LOGPDF = lambda x: norm.logpdf(x, loc = MU0, scale = SIGMA0)
MIN_INIT, MAX_INIT = norm.ppf(1e-5, loc = MU0, scale = SIGMA0), norm.ppf(1-1e-5, loc = MU0, scale = SIGMA0)
prior = stats.norm(loc = MU0, scale = SIGMA0)
N_EPSILON = 1000000
zs, mus, dists, key = ABC_gauss(key, TRUE_DATA, np.inf, N_EPSILON)
ALPHAS = [.99,.9, .75,.5,.25, .1,.05, .01, .005, .001, .0005,.0001]
EPSILONS = {1.: jnp.inf}
for alpha in ALPHAS: 
    EPSILONS[alpha] = jnp.quantile(dists, alpha)

ALPHAS = [1.]+ALPHAS

# %% [markdown]
# # Training loop

# %%
key = random.PRNGKey(0)

N_KDE = 10000
N_POINTS = 1000000
N_POINTS_EPS = 100000
N_SAMPLE = 10000
N_SAMPLES = 1


N_EPOCHS = 100
LEARNING_RATE = 0.001
PATIENCE = 7
COOLDOWN = 0
FACTOR = .5
RTOL = 1e-4  
ACCUMULATION_SIZE = 200
LEARNING_RATE_MIN = 1e-6

BATCH_SIZE = 256
NUM_BATCH = 1024
HIDDEN_SIZE = 256
NUM_LAYERS = 7
WDECAY = .001
N_GRID = 10000

NN_ARGS = {
    "N_EPOCH": N_EPOCHS,
    "NUM_LAYERS": NUM_LAYERS,
    "HIDDEN_SIZE": HIDDEN_SIZE,
    "BATCH_SIZE": BATCH_SIZE,
    "NUM_BATCH": NUM_BATCH,
    "LEARNING_RATE": LEARNING_RATE,
    "WDECAY": WDECAY,
    "PATIENCE": PATIENCE,
    "COOLDOWN": COOLDOWN,
    "FACTOR": FACTOR,
    "RTOL": RTOL,
    "ACCUMULATION_SIZE": ACCUMULATION_SIZE,
    "LEARNING_RATE_MIN": LEARNING_RATE_MIN
}

METRICS_TO_TEST ={"C2ST": c2stest, "RS_stat": ranksumstest_stat, "RS_pvalue": ranksumstest_pvalue}

METRICS = {}
PARAMS = {}
TRAIN_ACCURACY = {}
TEST_ACCURACY = {}
TIME_TRAINING = {}
TIME_SIM = {}
TIME_METRICS = {}
THETAS_ABC = {}
for alpha in tqdm(ALPHAS):
    EPSILON_STAR = EPSILONS[alpha]
    print(f"----------------------\nALPHA = {alpha} EPSILON = {EPSILON_STAR:.2}\n----------------------")


    print("Simulations of the dataset...")
    time_sim = time.time()
    key, subkey = random.split(key)
    X, y, key = get_dataset_gauss(subkey, N_POINTS, prior_simulator, data_simulator, discrepancy, EPSILON_STAR, TRUE_DATA)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
    time_sim = time.time()-time_sim
    
    thetas_abc = X[:N_KDE, 0]
    print('Time to simulate the dataset: {:.2f}s\n'.format(time_sim))
    N_POINTS_TRAIN, N_POINTS_TEST = X_train.shape[0], X_test.shape[0]

    print("Training the neural network...")
    time_nre = time.time()
    params, train_accuracy, train_losses, test_accuracy, test_losses, key = train_loop(key, NN_ARGS, prior_simulator, data_simulator, discrepancy, TRUE_DATA, X_train, y_train, X_test, y_test, N_POINTS_TRAIN, N_POINTS_TEST, EPSILON_STAR)
    time_nre = time.time()-time_nre
    print('Time to train the neural network: {:.2f}s\n'.format(time_nre))

    PARAMS[alpha] = params
    TRAIN_ACCURACY[alpha] = train_accuracy[-1]
    TEST_ACCURACY[alpha] = test_accuracy[-1]
    TIME_TRAINING[alpha] = time_nre
    TIME_SIM[alpha] = time_sim
    THETAS_ABC[alpha] = thetas_abc
    key, key_eval = random.split(key)
    print("Computing the metrics...")
    METRICS[alpha], time_metrics = evaluate_metrics(key_eval, METRICS_TO_TEST, TRUE_DATA, params, thetas_abc, prior, N_GRID, N_SAMPLE, N_SAMPLES, true_posterior_sample, N_KDE)
    TIME_METRICS[alpha] = time_metrics
    
    print('Time to compute the metrics: {:.2f}s\n'.format(time_metrics))
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]
# ----------------------
# ALPHA = 1.0 EPSILON = inf
# ----------------------
# Simulations of the dataset...
# Time to simulate the dataset: 4.56s
#
# Training the neural network...
# Initial accuracy: 47.36%, Initial test accuracy: 47.38%
# Training for 100 epochs...
# Epoch 1/100, mean train accuracy: 96.98%, mean test accuracy: 97.76%, lr scale: 1.0 in 16.18 sec
# Epoch 2/100, mean train accuracy: 97.69%, mean test accuracy: 97.49%, lr scale: 1.0 in 15.34 sec
# Epoch 3/100, mean train accuracy: 97.73%, mean test accuracy: 97.63%, lr scale: 1.0 in 15.56 sec
# Epoch 4/100, mean train accuracy: 97.78%, mean test accuracy: 96.47%, lr scale: 1.0 in 15.69 sec
# Epoch 5/100, mean train accuracy: 97.82%, mean test accuracy: 97.76%, lr scale: 1.0 in 15.44 sec
# Epoch 6/100, mean train accuracy: 97.82%, mean test accuracy: 97.70%, lr scale: 1.0 in 15.32 sec
# Epoch 7/100, mean train accuracy: 97.82%, mean test accuracy: 97.90%, lr scale: 0.5 in 15.59 sec
# Epoch 8/100, mean train accuracy: 97.89%, mean test accuracy: 97.93%, lr scale: 0.5 in 16.51 sec
# Epoch 9/100, mean train accuracy: 97.93%, mean test accuracy: 97.83%, lr scale: 0.5 in 16.00 sec
# Epoch 10/100, mean train accuracy: 97.94%, mean test accuracy: 97.94%, lr scale: 0.25 in 15.52 sec
# Epoch 11/100, mean train accuracy: 97.96%, mean test accuracy: 97.96%, lr scale: 0.125 in 15.68 sec
# Epoch 12/100, mean train accuracy: 98.01%, mean test accuracy: 97.92%, lr scale: 0.125 in 16.50 sec
# Epoch 13/100, mean train accuracy: 97.99%, mean test accuracy: 97.92%, lr scale: 0.0625 in 15.47 sec
# Epoch 14/100, mean train accuracy: 97.99%, mean test accuracy: 97.96%, lr scale: 0.03125 in 15.21 sec
# Epoch 15/100, mean train accuracy: 98.00%, mean test accuracy: 97.95%, lr scale: 0.03125 in 16.25 sec
# Epoch 16/100, mean train accuracy: 98.02%, mean test accuracy: 97.96%, lr scale: 0.015625 in 15.16 sec
# Epoch 17/100, mean train accuracy: 98.00%, mean test accuracy: 97.95%, lr scale: 0.0078125 in 15.78 sec
# Epoch 18/100, mean train accuracy: 98.01%, mean test accuracy: 97.96%, lr scale: 0.0078125 in 15.61 sec
# Epoch 19/100, mean train accuracy: 98.03%, mean test accuracy: 97.97%, lr scale: 0.0078125 in 15.64 sec
# Epoch 20/100, mean train accuracy: 98.01%, mean test accuracy: 97.96%, lr scale: 0.00390625 in 15.41 sec
# Epoch 21/100, mean train accuracy: 98.02%, mean test accuracy: 97.95%, lr scale: 0.00390625 in 15.08 sec
# Epoch 22/100, mean train accuracy: 98.02%, mean test accuracy: 97.99%, lr scale: 0.001953125 in 15.58 sec
# Epoch 23/100, mean train accuracy: 98.03%, mean test accuracy: 97.98%, lr scale: 0.001953125 in 17.62 sec
# Epoch 24/100, mean train accuracy: 97.98%, mean test accuracy: 97.95%, lr scale: 0.0009765625 in 16.19 sec
# Learning rate reached 1.00E-06, stopping training
# Time to train the neural network: 405.99s
#
# Computing the metrics...
# Evaluation of the metrics...
# Time to compute the metrics: 13.00s
#
# ----------------------
# ALPHA = 0.99 EPSILON = 7.4e+03
# ----------------------
# Simulations of the dataset...
# Time to simulate the dataset: 1.77s
#
# Training the neural network...
# Initial accuracy: 60.12%, Initial test accuracy: 60.06%
# Training for 100 epochs...
# Epoch 1/100, mean train accuracy: 96.95%, mean test accuracy: 97.41%, lr scale: 1.0 in 16.83 sec
# Epoch 2/100, mean train accuracy: 97.62%, mean test accuracy: 97.78%, lr scale: 1.0 in 15.26 sec
# Epoch 3/100, mean train accuracy: 97.66%, mean test accuracy: 97.72%, lr scale: 1.0 in 15.89 sec
# Epoch 4/100, mean train accuracy: 97.66%, mean test accuracy: 97.23%, lr scale: 1.0 in 16.34 sec
# Epoch 5/100, mean train accuracy: 97.78%, mean test accuracy: 97.87%, lr scale: 0.5 in 16.08 sec
# Epoch 6/100, mean train accuracy: 97.79%, mean test accuracy: 97.78%, lr scale: 0.5 in 15.82 sec
# Epoch 7/100, mean train accuracy: 97.78%, mean test accuracy: 97.86%, lr scale: 0.5 in 15.33 sec
# Epoch 8/100, mean train accuracy: 97.85%, mean test accuracy: 97.91%, lr scale: 0.25 in 16.67 sec
# Epoch 9/100, mean train accuracy: 97.87%, mean test accuracy: 97.88%, lr scale: 0.25 in 17.71 sec
# Epoch 10/100, mean train accuracy: 97.86%, mean test accuracy: 97.94%, lr scale: 0.125 in 30.00 sec
# Epoch 11/100, mean train accuracy: 97.82%, mean test accuracy: 97.92%, lr scale: 0.125 in 27.65 sec
# Epoch 12/100, mean train accuracy: 97.90%, mean test accuracy: 97.94%, lr scale: 0.0625 in 26.69 sec
# Epoch 13/100, mean train accuracy: 97.89%, mean test accuracy: 97.94%, lr scale: 0.0625 in 26.66 sec
# Epoch 14/100, mean train accuracy: 97.90%, mean test accuracy: 97.95%, lr scale: 0.03125 in 23.79 sec
# Epoch 15/100, mean train accuracy: 97.90%, mean test accuracy: 97.95%, lr scale: 0.015625 in 18.49 sec
# Epoch 16/100, mean train accuracy: 97.91%, mean test accuracy: 97.95%, lr scale: 0.015625 in 24.85 sec
# Epoch 17/100, mean train accuracy: 97.91%, mean test accuracy: 97.94%, lr scale: 0.0078125 in 22.92 sec
# Epoch 18/100, mean train accuracy: 97.93%, mean test accuracy: 97.94%, lr scale: 0.00390625 in 20.81 sec
# Epoch 19/100, mean train accuracy: 97.92%, mean test accuracy: 97.96%, lr scale: 0.001953125 in 30.44 sec
# Epoch 20/100, mean train accuracy: 97.92%, mean test accuracy: 97.95%, lr scale: 0.001953125 in 32.98 sec
# Epoch 21/100, mean train accuracy: 97.91%, mean test accuracy: 97.96%, lr scale: 0.0009765625 in 21.34 sec
# Learning rate reached 1.00E-06, stopping training
# Time to train the neural network: 471.11s
#
# Computing the metrics...
# Evaluation of the metrics...
# Time to compute the metrics: 15.83s
#
# ----------------------
# ALPHA = 0.9 EPSILON = 4.3e+03
# ----------------------
# Simulations of the dataset...
# Time to simulate the dataset: 0.88s
#
# Training the neural network...
# Initial accuracy: 41.39%, Initial test accuracy: 41.39%
# Training for 100 epochs...
# Epoch 1/100, mean train accuracy: 96.50%, mean test accuracy: 97.34%, lr scale: 1.0 in 18.36 sec
# Epoch 2/100, mean train accuracy: 97.29%, mean test accuracy: 97.18%, lr scale: 1.0 in 32.73 sec
# Epoch 3/100, mean train accuracy: 97.30%, mean test accuracy: 97.42%, lr scale: 1.0 in 32.21 sec
# Epoch 4/100, mean train accuracy: 97.38%, mean test accuracy: 97.28%, lr scale: 1.0 in 30.12 sec
# Epoch 5/100, mean train accuracy: 97.42%, mean test accuracy: 97.55%, lr scale: 1.0 in 25.46 sec
# Epoch 6/100, mean train accuracy: 97.44%, mean test accuracy: 97.48%, lr scale: 1.0 in 32.24 sec
# Epoch 7/100, mean train accuracy: 97.54%, mean test accuracy: 97.41%, lr scale: 0.5 in 32.48 sec
# Epoch 8/100, mean train accuracy: 97.50%, mean test accuracy: 97.52%, lr scale: 0.5 in 30.40 sec
# Epoch 9/100, mean train accuracy: 97.56%, mean test accuracy: 97.55%, lr scale: 0.25 in 18.70 sec
# Epoch 10/100, mean train accuracy: 97.58%, mean test accuracy: 97.55%, lr scale: 0.25 in 22.41 sec
# Epoch 11/100, mean train accuracy: 97.57%, mean test accuracy: 97.60%, lr scale: 0.125 in 21.58 sec
# Epoch 12/100, mean train accuracy: 97.58%, mean test accuracy: 97.59%, lr scale: 0.0625 in 19.68 sec
# Epoch 13/100, mean train accuracy: 97.65%, mean test accuracy: 97.58%, lr scale: 0.0625 in 19.26 sec
# Epoch 14/100, mean train accuracy: 97.61%, mean test accuracy: 97.59%, lr scale: 0.0625 in 21.80 sec
# Epoch 15/100, mean train accuracy: 97.64%, mean test accuracy: 97.58%, lr scale: 0.0625 in 18.09 sec
# Epoch 16/100, mean train accuracy: 97.64%, mean test accuracy: 97.60%, lr scale: 0.03125 in 19.08 sec
# Epoch 17/100, mean train accuracy: 97.66%, mean test accuracy: 97.62%, lr scale: 0.015625 in 21.20 sec
# Epoch 18/100, mean train accuracy: 97.63%, mean test accuracy: 97.61%, lr scale: 0.015625 in 16.83 sec
# Epoch 19/100, mean train accuracy: 97.62%, mean test accuracy: 97.57%, lr scale: 0.0078125 in 17.71 sec
# Epoch 20/100, mean train accuracy: 97.59%, mean test accuracy: 97.60%, lr scale: 0.00390625 in 15.63 sec
# Epoch 21/100, mean train accuracy: 97.60%, mean test accuracy: 97.60%, lr scale: 0.00390625 in 15.62 sec
# Epoch 22/100, mean train accuracy: 97.61%, mean test accuracy: 97.57%, lr scale: 0.001953125 in 15.89 sec
# Epoch 23/100, mean train accuracy: 97.65%, mean test accuracy: 97.60%, lr scale: 0.0009765625 in 15.72 sec
# Learning rate reached 1.00E-06, stopping training
# Time to train the neural network: 537.16s
#
# Computing the metrics...
# Evaluation of the metrics...
# Time to compute the metrics: 11.94s
#
# ----------------------
# ALPHA = 0.75 EPSILON = 2.8e+03
# ----------------------
# Simulations of the dataset...
# Time to simulate the dataset: 0.93s
#
# Training the neural network...
# Initial accuracy: 56.30%, Initial test accuracy: 56.17%
# Training for 100 epochs...
# Epoch 1/100, mean train accuracy: 96.27%, mean test accuracy: 97.06%, lr scale: 1.0 in 16.19 sec
# Epoch 2/100, mean train accuracy: 96.91%, mean test accuracy: 97.08%, lr scale: 1.0 in 17.15 sec
# Epoch 3/100, mean train accuracy: 96.96%, mean test accuracy: 96.08%, lr scale: 1.0 in 19.23 sec
# Epoch 4/100, mean train accuracy: 96.99%, mean test accuracy: 97.02%, lr scale: 1.0 in 18.56 sec
# Epoch 5/100, mean train accuracy: 96.98%, mean test accuracy: 97.07%, lr scale: 1.0 in 19.23 sec
# Epoch 6/100, mean train accuracy: 97.07%, mean test accuracy: 97.12%, lr scale: 0.5 in 18.91 sec
# Epoch 7/100, mean train accuracy: 97.06%, mean test accuracy: 97.08%, lr scale: 0.5 in 22.84 sec
# Epoch 8/100, mean train accuracy: 97.11%, mean test accuracy: 97.06%, lr scale: 0.25 in 16.70 sec
# Epoch 9/100, mean train accuracy: 97.14%, mean test accuracy: 97.17%, lr scale: 0.125 in 16.97 sec
# Epoch 10/100, mean train accuracy: 97.17%, mean test accuracy: 97.16%, lr scale: 0.125 in 15.78 sec
# Epoch 11/100, mean train accuracy: 97.21%, mean test accuracy: 97.16%, lr scale: 0.0625 in 15.70 sec
# Epoch 12/100, mean train accuracy: 97.18%, mean test accuracy: 97.17%, lr scale: 0.0625 in 15.72 sec
# Epoch 13/100, mean train accuracy: 97.18%, mean test accuracy: 97.16%, lr scale: 0.03125 in 17.59 sec
# Epoch 14/100, mean train accuracy: 97.20%, mean test accuracy: 97.17%, lr scale: 0.03125 in 15.56 sec
# Epoch 15/100, mean train accuracy: 97.19%, mean test accuracy: 97.18%, lr scale: 0.03125 in 15.80 sec
# Epoch 16/100, mean train accuracy: 97.21%, mean test accuracy: 97.15%, lr scale: 0.015625 in 15.46 sec
# Epoch 17/100, mean train accuracy: 97.19%, mean test accuracy: 97.20%, lr scale: 0.0078125 in 16.62 sec
# Epoch 18/100, mean train accuracy: 97.19%, mean test accuracy: 97.19%, lr scale: 0.00390625 in 15.45 sec
# Epoch 19/100, mean train accuracy: 97.23%, mean test accuracy: 97.15%, lr scale: 0.00390625 in 16.22 sec
# Epoch 20/100, mean train accuracy: 97.22%, mean test accuracy: 97.20%, lr scale: 0.001953125 in 15.31 sec
# Epoch 21/100, mean train accuracy: 97.22%, mean test accuracy: 97.18%, lr scale: 0.0009765625 in 16.74 sec
# Learning rate reached 1.00E-06, stopping training
# Time to train the neural network: 374.04s
#
# Computing the metrics...
# Evaluation of the metrics...
# Time to compute the metrics: 10.67s
#
# ----------------------
# ALPHA = 0.5 EPSILON = 1.6e+03
# ----------------------
# Simulations of the dataset...
# Time to simulate the dataset: 1.01s
#
# Training the neural network...
# Initial accuracy: 36.45%, Initial test accuracy: 36.44%
# Training for 100 epochs...
# Epoch 1/100, mean train accuracy: 95.33%, mean test accuracy: 95.64%, lr scale: 1.0 in 16.27 sec
# Epoch 2/100, mean train accuracy: 96.05%, mean test accuracy: 95.77%, lr scale: 1.0 in 18.58 sec
# Epoch 3/100, mean train accuracy: 96.03%, mean test accuracy: 96.24%, lr scale: 1.0 in 15.50 sec
# Epoch 4/100, mean train accuracy: 96.09%, mean test accuracy: 96.16%, lr scale: 1.0 in 15.32 sec
# Epoch 5/100, mean train accuracy: 96.12%, mean test accuracy: 96.18%, lr scale: 1.0 in 16.83 sec
# Epoch 6/100, mean train accuracy: 96.16%, mean test accuracy: 96.14%, lr scale: 1.0 in 15.57 sec
# Epoch 7/100, mean train accuracy: 96.18%, mean test accuracy: 96.29%, lr scale: 1.0 in 15.60 sec
# Epoch 8/100, mean train accuracy: 96.19%, mean test accuracy: 96.22%, lr scale: 0.5 in 15.28 sec
# Epoch 9/100, mean train accuracy: 96.31%, mean test accuracy: 96.28%, lr scale: 0.5 in 16.66 sec
# Epoch 10/100, mean train accuracy: 96.23%, mean test accuracy: 96.29%, lr scale: 0.25 in 15.36 sec
# Epoch 11/100, mean train accuracy: 96.25%, mean test accuracy: 96.29%, lr scale: 0.125 in 16.54 sec
# Epoch 12/100, mean train accuracy: 96.29%, mean test accuracy: 96.29%, lr scale: 0.125 in 15.68 sec
# Epoch 13/100, mean train accuracy: 96.27%, mean test accuracy: 96.32%, lr scale: 0.0625 in 15.61 sec
# Epoch 14/100, mean train accuracy: 96.36%, mean test accuracy: 96.33%, lr scale: 0.03125 in 16.37 sec
# Epoch 15/100, mean train accuracy: 96.31%, mean test accuracy: 96.30%, lr scale: 0.03125 in 16.03 sec
# Epoch 16/100, mean train accuracy: 96.35%, mean test accuracy: 96.34%, lr scale: 0.015625 in 15.36 sec
# Epoch 17/100, mean train accuracy: 96.31%, mean test accuracy: 96.31%, lr scale: 0.015625 in 16.42 sec
# Epoch 18/100, mean train accuracy: 96.33%, mean test accuracy: 96.32%, lr scale: 0.0078125 in 15.39 sec
# Epoch 19/100, mean train accuracy: 96.35%, mean test accuracy: 96.33%, lr scale: 0.00390625 in 16.25 sec
# Epoch 20/100, mean train accuracy: 96.31%, mean test accuracy: 96.33%, lr scale: 0.00390625 in 15.70 sec
# Epoch 21/100, mean train accuracy: 96.34%, mean test accuracy: 96.32%, lr scale: 0.001953125 in 15.39 sec
# Epoch 22/100, mean train accuracy: 96.34%, mean test accuracy: 96.30%, lr scale: 0.0009765625 in 15.57 sec
# Learning rate reached 1.00E-06, stopping training
# Time to train the neural network: 368.31s
#
# Computing the metrics...
# Evaluation of the metrics...
# Time to compute the metrics: 12.47s
#
# ----------------------
# ALPHA = 0.25 EPSILON = 6.9e+02
# ----------------------
# Simulations of the dataset...
# Time to simulate the dataset: 0.89s
#
# Training the neural network...
# Initial accuracy: 44.80%, Initial test accuracy: 44.73%
# Training for 100 epochs...
# Epoch 1/100, mean train accuracy: 93.78%, mean test accuracy: 94.85%, lr scale: 1.0 in 16.33 sec
# Epoch 2/100, mean train accuracy: 94.87%, mean test accuracy: 94.97%, lr scale: 1.0 in 16.63 sec
# Epoch 3/100, mean train accuracy: 95.01%, mean test accuracy: 95.26%, lr scale: 0.5 in 15.32 sec
# Epoch 4/100, mean train accuracy: 95.08%, mean test accuracy: 95.08%, lr scale: 0.5 in 16.67 sec
# Epoch 5/100, mean train accuracy: 95.19%, mean test accuracy: 95.31%, lr scale: 0.25 in 15.62 sec
# Epoch 6/100, mean train accuracy: 95.25%, mean test accuracy: 95.27%, lr scale: 0.25 in 15.75 sec
# Epoch 7/100, mean train accuracy: 95.30%, mean test accuracy: 95.18%, lr scale: 0.125 in 15.64 sec
# Epoch 8/100, mean train accuracy: 95.34%, mean test accuracy: 95.16%, lr scale: 0.125 in 16.74 sec
# Epoch 9/100, mean train accuracy: 95.32%, mean test accuracy: 95.28%, lr scale: 0.125 in 15.47 sec
# Epoch 10/100, mean train accuracy: 95.30%, mean test accuracy: 95.26%, lr scale: 0.125 in 15.94 sec
# Epoch 11/100, mean train accuracy: 95.33%, mean test accuracy: 95.17%, lr scale: 0.125 in 16.48 sec
# Epoch 12/100, mean train accuracy: 95.36%, mean test accuracy: 95.31%, lr scale: 0.0625 in 15.75 sec
# Epoch 13/100, mean train accuracy: 95.35%, mean test accuracy: 95.25%, lr scale: 0.0625 in 16.57 sec
# Epoch 14/100, mean train accuracy: 95.32%, mean test accuracy: 95.25%, lr scale: 0.03125 in 15.62 sec
# Epoch 15/100, mean train accuracy: 95.34%, mean test accuracy: 95.30%, lr scale: 0.03125 in 16.74 sec
# Epoch 16/100, mean train accuracy: 95.32%, mean test accuracy: 95.33%, lr scale: 0.015625 in 15.34 sec
# Epoch 17/100, mean train accuracy: 95.37%, mean test accuracy: 95.37%, lr scale: 0.0078125 in 15.77 sec
# Epoch 18/100, mean train accuracy: 95.39%, mean test accuracy: 95.34%, lr scale: 0.0078125 in 15.80 sec
# Epoch 19/100, mean train accuracy: 95.34%, mean test accuracy: 95.29%, lr scale: 0.00390625 in 17.11 sec
# Epoch 20/100, mean train accuracy: 95.37%, mean test accuracy: 95.36%, lr scale: 0.001953125 in 15.46 sec
# Epoch 21/100, mean train accuracy: 95.36%, mean test accuracy: 95.29%, lr scale: 0.001953125 in 15.61 sec
# Epoch 22/100, mean train accuracy: 95.38%, mean test accuracy: 95.28%, lr scale: 0.0009765625 in 16.35 sec
# Learning rate reached 1.00E-06, stopping training
# Time to train the neural network: 370.89s
#
# Computing the metrics...
# Evaluation of the metrics...
# Time to compute the metrics: 12.25s
#
# ----------------------
# ALPHA = 0.1 EPSILON = 2.1e+02
# ----------------------
# Simulations of the dataset...
# Time to simulate the dataset: 1.06s
#
# Training the neural network...
# Initial accuracy: 49.96%, Initial test accuracy: 50.02%
# Training for 100 epochs...
# Epoch 1/100, mean train accuracy: 88.82%, mean test accuracy: 92.67%, lr scale: 1.0 in 17.11 sec
# Epoch 2/100, mean train accuracy: 93.17%, mean test accuracy: 93.76%, lr scale: 1.0 in 15.04 sec
# Epoch 3/100, mean train accuracy: 93.29%, mean test accuracy: 93.75%, lr scale: 1.0 in 15.81 sec
# Epoch 4/100, mean train accuracy: 93.34%, mean test accuracy: 93.83%, lr scale: 0.5 in 15.72 sec
# Epoch 5/100, mean train accuracy: 93.62%, mean test accuracy: 93.68%, lr scale: 0.5 in 15.70 sec
# Epoch 6/100, mean train accuracy: 93.70%, mean test accuracy: 93.52%, lr scale: 0.25 in 15.45 sec
# Epoch 7/100, mean train accuracy: 93.75%, mean test accuracy: 93.68%, lr scale: 0.25 in 16.38 sec
# Epoch 8/100, mean train accuracy: 93.69%, mean test accuracy: 93.89%, lr scale: 0.25 in 16.13 sec
# Epoch 9/100, mean train accuracy: 93.82%, mean test accuracy: 93.16%, lr scale: 0.25 in 15.86 sec
# Epoch 10/100, mean train accuracy: 93.85%, mean test accuracy: 93.88%, lr scale: 0.125 in 16.66 sec
# Epoch 11/100, mean train accuracy: 93.83%, mean test accuracy: 93.84%, lr scale: 0.0625 in 15.26 sec
# Epoch 12/100, mean train accuracy: 93.87%, mean test accuracy: 93.86%, lr scale: 0.0625 in 15.98 sec
# Epoch 13/100, mean train accuracy: 93.83%, mean test accuracy: 93.78%, lr scale: 0.0625 in 16.25 sec
# Epoch 14/100, mean train accuracy: 93.86%, mean test accuracy: 93.80%, lr scale: 0.03125 in 18.81 sec
# Epoch 15/100, mean train accuracy: 93.94%, mean test accuracy: 93.92%, lr scale: 0.015625 in 15.72 sec
# Epoch 16/100, mean train accuracy: 93.93%, mean test accuracy: 93.94%, lr scale: 0.015625 in 15.94 sec
# Epoch 17/100, mean train accuracy: 94.00%, mean test accuracy: 93.91%, lr scale: 0.0078125 in 15.91 sec
# Epoch 18/100, mean train accuracy: 94.00%, mean test accuracy: 93.91%, lr scale: 0.00390625 in 17.20 sec
# Epoch 19/100, mean train accuracy: 93.85%, mean test accuracy: 93.94%, lr scale: 0.001953125 in 15.85 sec
# Epoch 20/100, mean train accuracy: 93.90%, mean test accuracy: 93.98%, lr scale: 0.001953125 in 15.47 sec
# Epoch 21/100, mean train accuracy: 93.95%, mean test accuracy: 93.91%, lr scale: 0.0009765625 in 15.83 sec
# Learning rate reached 1.00E-06, stopping training
# Time to train the neural network: 354.48s
#
# Computing the metrics...
# Evaluation of the metrics...
# Time to compute the metrics: 11.31s
#
# ----------------------
# ALPHA = 0.05 EPSILON = 7e+01
# ----------------------
# Simulations of the dataset...
# Time to simulate the dataset: 0.97s
#
# Training the neural network...
# Initial accuracy: 50.65%, Initial test accuracy: 50.70%
# Training for 100 epochs...
# Epoch 1/100, mean train accuracy: 87.40%, mean test accuracy: 91.50%, lr scale: 1.0 in 17.07 sec
# Epoch 2/100, mean train accuracy: 91.18%, mean test accuracy: 91.70%, lr scale: 1.0 in 15.77 sec
# Epoch 3/100, mean train accuracy: 91.14%, mean test accuracy: 89.16%, lr scale: 1.0 in 15.46 sec
# Epoch 4/100, mean train accuracy: 91.58%, mean test accuracy: 92.00%, lr scale: 0.5 in 17.60 sec
# Epoch 5/100, mean train accuracy: 91.76%, mean test accuracy: 91.74%, lr scale: 0.25 in 12.47 sec
# Epoch 6/100, mean train accuracy: 91.79%, mean test accuracy: 91.33%, lr scale: 0.25 in 12.01 sec
# Epoch 7/100, mean train accuracy: 91.76%, mean test accuracy: 92.04%, lr scale: 0.25 in 12.20 sec
# Epoch 8/100, mean train accuracy: 91.74%, mean test accuracy: 91.99%, lr scale: 0.25 in 12.14 sec
# Epoch 9/100, mean train accuracy: 91.88%, mean test accuracy: 91.77%, lr scale: 0.125 in 11.70 sec
# Epoch 10/100, mean train accuracy: 91.86%, mean test accuracy: 91.90%, lr scale: 0.0625 in 11.75 sec
# Epoch 11/100, mean train accuracy: 91.96%, mean test accuracy: 92.09%, lr scale: 0.0625 in 5666.77 sec
# Epoch 12/100, mean train accuracy: 91.96%, mean test accuracy: 92.06%, lr scale: 0.0625 in 18.58 sec
# Epoch 13/100, mean train accuracy: 91.97%, mean test accuracy: 92.03%, lr scale: 0.03125 in 925.56 sec
# Epoch 14/100, mean train accuracy: 92.02%, mean test accuracy: 92.09%, lr scale: 0.03125 in 20.21 sec
# Epoch 15/100, mean train accuracy: 92.05%, mean test accuracy: 92.04%, lr scale: 0.015625 in 2699.98 sec
# Epoch 16/100, mean train accuracy: 91.97%, mean test accuracy: 92.04%, lr scale: 0.015625 in 3663.56 sec
# Epoch 17/100, mean train accuracy: 92.05%, mean test accuracy: 92.14%, lr scale: 0.0078125 in 3667.15 sec
# Epoch 18/100, mean train accuracy: 92.02%, mean test accuracy: 92.09%, lr scale: 0.00390625 in 1846.42 sec
# Epoch 19/100, mean train accuracy: 92.08%, mean test accuracy: 92.12%, lr scale: 0.001953125 in 765.37 sec
# Epoch 20/100, mean train accuracy: 92.00%, mean test accuracy: 92.12%, lr scale: 0.001953125 in 201.64 sec
# Epoch 21/100, mean train accuracy: 92.09%, mean test accuracy: 92.10%, lr scale: 0.0009765625 in 802.93 sec
# Learning rate reached 1.00E-06, stopping training
# Time to train the neural network: 20433.07s
#
# Computing the metrics...
# Evaluation of the metrics...
# Time to compute the metrics: 85.22s
#
# ----------------------
# ALPHA = 0.01 EPSILON = 3.4
# ----------------------
# Simulations of the dataset...
# Time to simulate the dataset: 1.08s
#
# Training the neural network...
# Initial accuracy: 50.07%, Initial test accuracy: 49.90%
# Training for 100 epochs...
# Epoch 1/100, mean train accuracy: 52.77%, mean test accuracy: 70.23%, lr scale: 1.0 in 305.91 sec
# Epoch 2/100, mean train accuracy: 72.80%, mean test accuracy: 76.73%, lr scale: 1.0 in 520.20 sec
# Epoch 3/100, mean train accuracy: 76.80%, mean test accuracy: 77.89%, lr scale: 1.0 in 435.99 sec
# Epoch 4/100, mean train accuracy: 77.10%, mean test accuracy: 77.05%, lr scale: 1.0 in 47.39 sec
# Epoch 5/100, mean train accuracy: 77.49%, mean test accuracy: 77.55%, lr scale: 0.5 in 104.82 sec
# Epoch 6/100, mean train accuracy: 77.42%, mean test accuracy: 77.99%, lr scale: 0.25 in 56.45 sec
# Epoch 7/100, mean train accuracy: 77.77%, mean test accuracy: 77.21%, lr scale: 0.25 in 54.14 sec
# Epoch 8/100, mean train accuracy: 77.60%, mean test accuracy: 77.98%, lr scale: 0.125 in 396.74 sec
# Epoch 9/100, mean train accuracy: 77.89%, mean test accuracy: 77.80%, lr scale: 0.125 in 147.78 sec
# Epoch 10/100, mean train accuracy: 77.70%, mean test accuracy: 77.76%, lr scale: 0.0625 in 22.80 sec
# Epoch 11/100, mean train accuracy: 77.91%, mean test accuracy: 77.92%, lr scale: 0.0625 in 21.03 sec
# Epoch 12/100, mean train accuracy: 77.94%, mean test accuracy: 77.94%, lr scale: 0.03125 in 25.51 sec
# Epoch 13/100, mean train accuracy: 77.99%, mean test accuracy: 77.98%, lr scale: 0.03125 in 22.65 sec
# Epoch 14/100, mean train accuracy: 77.89%, mean test accuracy: 77.95%, lr scale: 0.03125 in 25.27 sec
# Epoch 15/100, mean train accuracy: 78.03%, mean test accuracy: 77.97%, lr scale: 0.015625 in 19.14 sec
# Epoch 16/100, mean train accuracy: 78.09%, mean test accuracy: 77.93%, lr scale: 0.0078125 in 17.33 sec
# Epoch 17/100, mean train accuracy: 77.95%, mean test accuracy: 77.93%, lr scale: 0.0078125 in 19.07 sec
# Epoch 18/100, mean train accuracy: 77.93%, mean test accuracy: 77.94%, lr scale: 0.0078125 in 17.81 sec
# Epoch 19/100, mean train accuracy: 77.99%, mean test accuracy: 77.97%, lr scale: 0.00390625 in 17.43 sec
# Epoch 20/100, mean train accuracy: 77.88%, mean test accuracy: 77.95%, lr scale: 0.001953125 in 18.75 sec
# Epoch 21/100, mean train accuracy: 78.04%, mean test accuracy: 77.91%, lr scale: 0.001953125 in 19.01 sec
# Epoch 22/100, mean train accuracy: 78.04%, mean test accuracy: 78.00%, lr scale: 0.0009765625 in 17.60 sec
# Learning rate reached 1.00E-06, stopping training
# Time to train the neural network: 3317.29s
#
# Computing the metrics...
# Evaluation of the metrics...
# Time to compute the metrics: 13.24s
#
# ----------------------
# ALPHA = 0.005 EPSILON = 0.84
# ----------------------
# Simulations of the dataset...
# Time to simulate the dataset: 1.03s
#
# Training the neural network...
# Initial accuracy: 49.99%, Initial test accuracy: 50.02%
# Training for 100 epochs...
# Epoch 1/100, mean train accuracy: 50.11%, mean test accuracy: 49.99%, lr scale: 1.0 in 20.68 sec
# Epoch 2/100, mean train accuracy: 49.94%, mean test accuracy: 49.99%, lr scale: 1.0 in 17.31 sec
# Epoch 3/100, mean train accuracy: 50.26%, mean test accuracy: 49.95%, lr scale: 1.0 in 16.98 sec
# Epoch 4/100, mean train accuracy: 50.48%, mean test accuracy: 49.97%, lr scale: 0.5 in 20.07 sec
# Epoch 5/100, mean train accuracy: 49.97%, mean test accuracy: 50.01%, lr scale: 0.25 in 16.95 sec
# Epoch 6/100, mean train accuracy: 51.15%, mean test accuracy: 56.91%, lr scale: 0.25 in 17.29 sec
# Epoch 7/100, mean train accuracy: 51.55%, mean test accuracy: 50.01%, lr scale: 0.25 in 18.38 sec
# Epoch 8/100, mean train accuracy: 58.85%, mean test accuracy: 65.63%, lr scale: 0.125 in 17.92 sec
# Epoch 9/100, mean train accuracy: 66.03%, mean test accuracy: 65.44%, lr scale: 0.125 in 18.38 sec
# Epoch 10/100, mean train accuracy: 66.17%, mean test accuracy: 66.86%, lr scale: 0.125 in 30.05 sec
# Epoch 11/100, mean train accuracy: 66.70%, mean test accuracy: 66.84%, lr scale: 0.125 in 21.74 sec
# Epoch 12/100, mean train accuracy: 67.00%, mean test accuracy: 67.57%, lr scale: 0.125 in 19.25 sec
# Epoch 13/100, mean train accuracy: 67.08%, mean test accuracy: 67.23%, lr scale: 0.125 in 19.24 sec
# Epoch 14/100, mean train accuracy: 67.15%, mean test accuracy: 67.32%, lr scale: 0.125 in 18.50 sec
# Epoch 15/100, mean train accuracy: 67.08%, mean test accuracy: 66.41%, lr scale: 0.125 in 18.07 sec
# Epoch 16/100, mean train accuracy: 67.37%, mean test accuracy: 67.81%, lr scale: 0.125 in 18.62 sec
# Epoch 17/100, mean train accuracy: 67.47%, mean test accuracy: 67.22%, lr scale: 0.0625 in 18.99 sec
# Epoch 18/100, mean train accuracy: 67.64%, mean test accuracy: 67.97%, lr scale: 0.0625 in 17.89 sec
# Epoch 19/100, mean train accuracy: 67.64%, mean test accuracy: 68.14%, lr scale: 0.0625 in 19.25 sec
# Epoch 20/100, mean train accuracy: 67.89%, mean test accuracy: 68.26%, lr scale: 0.0625 in 17.58 sec
# Epoch 21/100, mean train accuracy: 67.90%, mean test accuracy: 68.05%, lr scale: 0.0625 in 17.01 sec
# Epoch 22/100, mean train accuracy: 68.06%, mean test accuracy: 68.07%, lr scale: 0.0625 in 17.43 sec
# Epoch 23/100, mean train accuracy: 68.16%, mean test accuracy: 68.03%, lr scale: 0.03125 in 15.81 sec
# Epoch 24/100, mean train accuracy: 68.11%, mean test accuracy: 67.49%, lr scale: 0.03125 in 16.26 sec
# Epoch 25/100, mean train accuracy: 68.34%, mean test accuracy: 68.38%, lr scale: 0.015625 in 20.77 sec
# Epoch 26/100, mean train accuracy: 68.46%, mean test accuracy: 68.39%, lr scale: 0.015625 in 23.88 sec
# Epoch 27/100, mean train accuracy: 68.41%, mean test accuracy: 68.37%, lr scale: 0.0078125 in 23.73 sec
# Epoch 28/100, mean train accuracy: 68.56%, mean test accuracy: 68.41%, lr scale: 0.00390625 in 19.29 sec
# Epoch 29/100, mean train accuracy: 68.37%, mean test accuracy: 68.48%, lr scale: 0.00390625 in 20.06 sec
# Epoch 30/100, mean train accuracy: 68.34%, mean test accuracy: 68.40%, lr scale: 0.001953125 in 22.67 sec
# Epoch 31/100, mean train accuracy: 68.42%, mean test accuracy: 68.41%, lr scale: 0.0009765625 in 22.59 sec
# Learning rate reached 1.00E-06, stopping training
# Time to train the neural network: 624.67s
#
# Computing the metrics...
# Evaluation of the metrics...
# Time to compute the metrics: 20.14s
#
# ----------------------
# ALPHA = 0.001 EPSILON = 0.036
# ----------------------
# Simulations of the dataset...
# Time to simulate the dataset: 1.14s
#
# Training the neural network...
# Initial accuracy: 50.00%, Initial test accuracy: 50.02%
# Training for 100 epochs...
# Epoch 1/100, mean train accuracy: 50.00%, mean test accuracy: 49.96%, lr scale: 1.0 in 27.97 sec
# Epoch 2/100, mean train accuracy: 50.04%, mean test accuracy: 49.95%, lr scale: 1.0 in 23.59 sec
# Epoch 3/100, mean train accuracy: 50.09%, mean test accuracy: 50.01%, lr scale: 1.0 in 21.76 sec
# Epoch 4/100, mean train accuracy: 50.14%, mean test accuracy: 50.02%, lr scale: 0.5 in 22.84 sec
# Epoch 5/100, mean train accuracy: 50.00%, mean test accuracy: 50.00%, lr scale: 0.5 in 19.47 sec
# Epoch 6/100, mean train accuracy: 50.17%, mean test accuracy: 50.02%, lr scale: 0.25 in 19.08 sec
# Epoch 7/100, mean train accuracy: 50.09%, mean test accuracy: 49.93%, lr scale: 0.25 in 26.54 sec
# Epoch 8/100, mean train accuracy: 50.04%, mean test accuracy: 50.05%, lr scale: 0.25 in 20.33 sec
# Epoch 9/100, mean train accuracy: 49.90%, mean test accuracy: 50.01%, lr scale: 0.125 in 27.82 sec
# Epoch 10/100, mean train accuracy: 50.24%, mean test accuracy: 49.98%, lr scale: 0.125 in 25.49 sec
# Epoch 11/100, mean train accuracy: 50.04%, mean test accuracy: 49.97%, lr scale: 0.0625 in 19.44 sec
# Epoch 12/100, mean train accuracy: 50.20%, mean test accuracy: 50.00%, lr scale: 0.0625 in 17.27 sec
# Epoch 13/100, mean train accuracy: 50.12%, mean test accuracy: 50.04%, lr scale: 0.0625 in 17.61 sec
# Epoch 14/100, mean train accuracy: 49.95%, mean test accuracy: 50.05%, lr scale: 0.03125 in 22.31 sec
# Epoch 15/100, mean train accuracy: 50.06%, mean test accuracy: 49.88%, lr scale: 0.015625 in 18.25 sec
# Epoch 16/100, mean train accuracy: 50.01%, mean test accuracy: 49.95%, lr scale: 0.015625 in 19.18 sec
# Epoch 17/100, mean train accuracy: 49.87%, mean test accuracy: 49.95%, lr scale: 0.0078125 in 20.39 sec
# Epoch 18/100, mean train accuracy: 50.00%, mean test accuracy: 50.02%, lr scale: 0.00390625 in 16.22 sec
# Epoch 19/100, mean train accuracy: 50.04%, mean test accuracy: 50.10%, lr scale: 0.001953125 in 16.49 sec
# Epoch 20/100, mean train accuracy: 50.12%, mean test accuracy: 49.93%, lr scale: 0.001953125 in 15.85 sec
# Epoch 21/100, mean train accuracy: 49.92%, mean test accuracy: 49.95%, lr scale: 0.0009765625 in 16.78 sec
# Learning rate reached 1.00E-06, stopping training
# Time to train the neural network: 463.66s
#
# Computing the metrics...
# Evaluation of the metrics...
# Time to compute the metrics: 11.98s
#
# ----------------------
# ALPHA = 0.0005 EPSILON = 0.0079
# ----------------------
# Simulations of the dataset...
# Time to simulate the dataset: 0.95s
#
# Training the neural network...
# Initial accuracy: 49.95%, Initial test accuracy: 50.00%
# Training for 100 epochs...
# Epoch 1/100, mean train accuracy: 50.12%, mean test accuracy: 50.03%, lr scale: 1.0 in 17.05 sec
# Epoch 2/100, mean train accuracy: 49.93%, mean test accuracy: 50.06%, lr scale: 1.0 in 19.09 sec
# Epoch 3/100, mean train accuracy: 50.10%, mean test accuracy: 50.04%, lr scale: 1.0 in 17.16 sec
# Epoch 4/100, mean train accuracy: 49.86%, mean test accuracy: 49.99%, lr scale: 0.5 in 17.10 sec
# Epoch 5/100, mean train accuracy: 50.05%, mean test accuracy: 49.92%, lr scale: 0.5 in 18.05 sec
# Epoch 6/100, mean train accuracy: 50.05%, mean test accuracy: 49.98%, lr scale: 0.25 in 17.13 sec
# Epoch 7/100, mean train accuracy: 50.03%, mean test accuracy: 49.96%, lr scale: 0.25 in 17.03 sec
# Epoch 8/100, mean train accuracy: 50.07%, mean test accuracy: 50.09%, lr scale: 0.125 in 18.07 sec
# Epoch 9/100, mean train accuracy: 49.94%, mean test accuracy: 50.06%, lr scale: 0.0625 in 17.94 sec
# Epoch 10/100, mean train accuracy: 49.91%, mean test accuracy: 50.00%, lr scale: 0.0625 in 16.38 sec
# Epoch 11/100, mean train accuracy: 49.89%, mean test accuracy: 49.97%, lr scale: 0.03125 in 16.32 sec
# Epoch 12/100, mean train accuracy: 50.09%, mean test accuracy: 50.00%, lr scale: 0.03125 in 16.88 sec
# Epoch 13/100, mean train accuracy: 50.09%, mean test accuracy: 50.08%, lr scale: 0.015625 in 16.59 sec
# Epoch 14/100, mean train accuracy: 49.88%, mean test accuracy: 50.04%, lr scale: 0.015625 in 16.53 sec
# Epoch 15/100, mean train accuracy: 50.13%, mean test accuracy: 49.99%, lr scale: 0.0078125 in 16.60 sec
# Epoch 16/100, mean train accuracy: 50.06%, mean test accuracy: 49.97%, lr scale: 0.00390625 in 16.60 sec
# Epoch 17/100, mean train accuracy: 50.07%, mean test accuracy: 50.02%, lr scale: 0.001953125 in 17.73 sec
# Epoch 18/100, mean train accuracy: 50.05%, mean test accuracy: 50.01%, lr scale: 0.001953125 in 16.40 sec
# Epoch 19/100, mean train accuracy: 49.97%, mean test accuracy: 49.97%, lr scale: 0.0009765625 in 16.74 sec
# Learning rate reached 1.00E-06, stopping training
# Time to train the neural network: 343.68s
#
# Computing the metrics...
# Evaluation of the metrics...
# Time to compute the metrics: 11.92s
#
# ----------------------
# ALPHA = 0.0001 EPSILON = 0.00036
# ----------------------
# Simulations of the dataset...
# Time to simulate the dataset: 0.96s
#
# Training the neural network...
# Initial accuracy: 50.00%, Initial test accuracy: 49.92%
# Training for 100 epochs...
# Epoch 1/100, mean train accuracy: 50.05%, mean test accuracy: 49.96%, lr scale: 1.0 in 18.54 sec
# Epoch 2/100, mean train accuracy: 50.00%, mean test accuracy: 50.00%, lr scale: 1.0 in 17.41 sec
# Epoch 3/100, mean train accuracy: 49.96%, mean test accuracy: 50.03%, lr scale: 1.0 in 16.29 sec
# Epoch 4/100, mean train accuracy: 49.99%, mean test accuracy: 50.09%, lr scale: 0.5 in 18.01 sec
# Epoch 5/100, mean train accuracy: 49.97%, mean test accuracy: 50.10%, lr scale: 0.5 in 17.29 sec
# Epoch 6/100, mean train accuracy: 50.15%, mean test accuracy: 49.97%, lr scale: 0.25 in 17.26 sec
# Epoch 7/100, mean train accuracy: 49.93%, mean test accuracy: 49.93%, lr scale: 0.25 in 17.18 sec
# Epoch 8/100, mean train accuracy: 50.09%, mean test accuracy: 49.98%, lr scale: 0.125 in 17.34 sec
# Epoch 9/100, mean train accuracy: 49.94%, mean test accuracy: 50.02%, lr scale: 0.125 in 16.79 sec
# Epoch 10/100, mean train accuracy: 49.95%, mean test accuracy: 50.04%, lr scale: 0.0625 in 16.48 sec
# Epoch 11/100, mean train accuracy: 49.92%, mean test accuracy: 49.94%, lr scale: 0.0625 in 17.49 sec
# Epoch 12/100, mean train accuracy: 50.01%, mean test accuracy: 50.07%, lr scale: 0.03125 in 17.82 sec
# Epoch 13/100, mean train accuracy: 49.93%, mean test accuracy: 49.98%, lr scale: 0.03125 in 17.48 sec
# Epoch 14/100, mean train accuracy: 49.96%, mean test accuracy: 50.01%, lr scale: 0.015625 in 16.55 sec
# Epoch 15/100, mean train accuracy: 50.13%, mean test accuracy: 50.02%, lr scale: 0.0078125 in 16.64 sec
# Epoch 16/100, mean train accuracy: 49.94%, mean test accuracy: 50.09%, lr scale: 0.0078125 in 16.78 sec
# Epoch 17/100, mean train accuracy: 50.01%, mean test accuracy: 50.07%, lr scale: 0.00390625 in 16.51 sec
# Epoch 18/100, mean train accuracy: 50.00%, mean test accuracy: 49.95%, lr scale: 0.001953125 in 16.78 sec
# Epoch 19/100, mean train accuracy: 49.86%, mean test accuracy: 49.96%, lr scale: 0.0009765625 in 18.09 sec
# Learning rate reached 1.00E-06, stopping training
# Time to train the neural network: 344.22s
#
# Computing the metrics...
# Evaluation of the metrics...
# Time to compute the metrics: 11.38s

# %% [markdown]
# # Save results

# %%
PATH_RESULTS = os.getcwd()+"/examples/Gauss-Gauss/Gauss_Gauss_1D_known_sigma/notebook_results/mu_{:.3}".format(TRUE_MU)
if not os.path.exists(PATH_RESULTS):
    os.makedirs(PATH_RESULTS)
print(PATH_RESULTS)
# Out:
# /Users/antoineluciano/Documents/Recherche/ABC-SBI/examples/Gauss-Gauss/Gauss_Gauss_1D_known_sigma/notebook_results/mu_40.0

# %% [markdown]
# ## Params dictionary in a Pickle

# %%
with lzma.open(PATH_RESULTS+'/params.xz', 'wb') as f:
    pickle.dump(PARAMS, f)

# %% [markdown]
# ## $\theta$ from ABC pseudo posterior (for KDE approx) in a Pickle

# %%
with lzma.open(PATH_RESULTS+'/thetas_abc.xz', 'wb') as f:
    pickle.dump(THETAS_ABC, f)

# %% [markdown]
# ## Comp. time and metrics in a CSV

# %%
create_csv_for_a_dataset(ALPHAS = ALPHAS, EPSILONS=EPSILONS, TEST_ACCURACY=TEST_ACCURACY, TRAIN_ACCURACY=TRAIN_ACCURACY, TIME_SIMULATIONS=TIME_SIM, TIME_TRAINING=TIME_TRAINING, TIME_EVAL=TIME_METRICS, METRICS = METRICS, TRUE_DATA=TRUE_DATA, TRUE_THETA=[TRUE_MU], PRIOR_ARGS={"mu0": MU0, "sigma0": SIGMA0}, MODEL_ARGS={"sigma": SIGMA}, NN_ARGS=NN_ARGS, INDEX_MARGINAL=0, file_name=PATH_RESULTS+"/results.csv")
# Out:
# CSV CREATED at /Users/antoineluciano/Documents/Recherche/ABC-SBI/examples/Gauss-Gauss/Gauss_Gauss_1D_known_sigma/notebook_results/mu_40.0/results.csv

# %%
df_results = pd.read_csv(PATH_RESULTS+"/results.csv")
df_results
# Out:
#       alpha   epsilon method             metric  metric_value  sigma  mu0  \
# 0    1.0000       inf    ABC               C2ST      0.995350    1.0  0.0
# 1    1.0000       inf    ABC            RS_stat    115.464497    1.0  0.0
# 2    1.0000       inf    ABC          RS_pvalue      0.000000    1.0  0.0
# 3    1.0000       inf    NRE               C2ST      0.523950    1.0  0.0
# 4    1.0000       inf    NRE            RS_stat      6.564839    1.0  0.0
# ..      ...       ...    ...                ...           ...    ...  ...
# 177  0.0001  0.000355    ALL    TIME_SIMULATION      0.963666    1.0  0.0
# 178  0.0001  0.000355    ALL      TIME_TRAINING    344.215409    1.0  0.0
# 179  0.0001  0.000355    ALL          TIME_EVAL     11.375820    1.0  0.0
# 180  0.0001  0.000355    ALL  NN_TRAIN_ACCURACY      0.498558    1.0  0.0
# 181  0.0001  0.000355    ALL   NN_TEST_ACCURACY      0.499557    1.0  0.0
#
#      sigma0  N_EPOCH  NUM_LAYERS  ...    RTOL  ACCUMULATION_SIZE  \
# 0      20.0      100           7  ...  0.0001                200
# 1      20.0      100           7  ...  0.0001                200
# 2      20.0      100           7  ...  0.0001                200
# 3      20.0      100           7  ...  0.0001                200
# 4      20.0      100           7  ...  0.0001                200
# ..      ...      ...         ...  ...     ...                ...
# 177    20.0      100           7  ...  0.0001                200
# 178    20.0      100           7  ...  0.0001                200
# 179    20.0      100           7  ...  0.0001                200
# 180    20.0      100           7  ...  0.0001                200
# 181    20.0      100           7  ...  0.0001                200
#
#      LEARNING_RATE_MIN  true_theta_1  index_marginal     xobs_1     xobs_2  \
# 0             0.000001          40.0               0  38.541805  37.952957
# 1             0.000001          40.0               0  38.541805  37.952957
# 2             0.000001          40.0               0  38.541805  37.952957
# 3             0.000001          40.0               0  38.541805  37.952957
# 4             0.000001          40.0               0  38.541805  37.952957
# ..                 ...           ...             ...        ...        ...
# 177           0.000001          40.0               0  38.541805  37.952957
# 178           0.000001          40.0               0  38.541805  37.952957
# 179           0.000001          40.0               0  38.541805  37.952957
# 180           0.000001          40.0               0  38.541805  37.952957
# 181           0.000001          40.0               0  38.541805  37.952957
#
#        xobs_3    xobs_4     xobs_5
# 0    42.04734  41.16841  39.024162
# 1    42.04734  41.16841  39.024162
# 2    42.04734  41.16841  39.024162
# 3    42.04734  41.16841  39.024162
# 4    42.04734  41.16841  39.024162
# ..        ...       ...        ...
# 177  42.04734  41.16841  39.024162
# 178  42.04734  41.16841  39.024162
# 179  42.04734  41.16841  39.024162
# 180  42.04734  41.16841  39.024162
# 181  42.04734  41.16841  39.024162
#
# [182 rows x 28 columns]

# %% [markdown]
# # Display results

# %% [markdown]
# ## ABC-NRE Approximation

# %%
MIN_INIT, MAX_INIT = -100, 100
PRIOR_LOGPDF = lambda x: norm.logpdf(x, loc = MU0, scale = SIGMA0)
prior_pdf = lambda x: norm.pdf(x, loc = MU0, scale = SIGMA0)
prior = stats.norm(loc = MU0, scale = SIGMA0)
posterior = true_post
likelihood = lambda x: jnp.exp(jnp.sum((x-TRUE_DATA)**2)/(2*SIGMA**2))
grid_prior, pdf_prior = find_grid_explorative(prior_pdf, 10000, 10000, MIN_INIT, MAX_INIT)
grid_true, pdf_true = find_grid_explorative(lambda x: true_post(TRUE_DATA).pdf(x), 10000, 10000, MIN_INIT, MAX_INIT)

Z_prior = np.trapz(pdf_prior, grid_prior)
Z_true = np.trapz(pdf_true, grid_true)

for alpha in ALPHAS:
    EPSILON_STAR = EPSILONS[alpha]
    # kde_approx = lambda x: true_pseudo_post(x, np.mean(TRUE_DATA), EPSILON_STAR, prior)
    kde_approx = gaussian_kde(THETAS_ABC[alpha])
    params = PARAMS[alpha] 
    grid_pseudo, pdf_pseudo = find_grid_explorative(lambda x: true_pseudo_post(x, np.mean(TRUE_DATA), EPSILON_STAR, prior), 10000, 10000, MIN_INIT, MAX_INIT)
    
    grid_nre, pdf_nre = find_grid_explorative(lambda x:NRE_posterior_pdf(params, x, TRUE_DATA, PRIOR_LOGPDF), 10000, 10000, MIN_INIT, MAX_INIT)
    
    grid_nre_corrected, pdf_nre_corrected = find_grid_explorative(lambda x: NRE_corrected_posterior_pdf(params, x, TRUE_DATA, kde_approx), 10000, 10000, MIN_INIT, MAX_INIT)
    
    Z_pseudo = np.trapz(pdf_pseudo, grid_pseudo)
    Z_nre = np.trapz(pdf_nre, grid_nre)
    Z_nre_corrected = np.trapz(pdf_nre_corrected, grid_nre_corrected)
    
    plt.plot(grid_nre, pdf_nre/Z_nre, label = 'NRE Approx. no ABC correction', color = "red")
    plt.plot(grid_pseudo, pdf_pseudo/Z_pseudo, label = "ABC pseudo-post", color = "orange")

    plt.plot(grid_nre_corrected, pdf_nre_corrected/Z_nre_corrected, label = "NRE Approx. with ABC correction", color = "blue", linestyle = "--")
    plt.plot(grid_prior, pdf_prior/Z_prior, label = 'Prior', color = "grey", linestyle = "--")
    plt.plot(grid_true, pdf_true/Z_true, label = 'True Posterior', color = "green")

    plt.xlim(np.min(grid_true), np.max(grid_true))
    plt.title(f"Posterior comparison for $\epsilon =$ {alpha:.3%} \nNN Accuracy = {TEST_ACCURACY[alpha]:.2%}")
    plt.legend()
    plt.show()
    df_figure = pd.DataFrame()
    df_figure["grid_nre"] = grid_nre
    df_figure["pdf_nre"] = pdf_nre
    df_figure["grid_pseudo"] = grid_pseudo
    df_figure["pdf_pseudo"] = pdf_pseudo
    df_figure["grid_nre_corrected"] = grid_nre_corrected
    df_figure["pdf_nre_corrected"] = pdf_nre_corrected
    df_figure["grid_prior"] = grid_prior
    df_figure["pdf_prior"] = pdf_prior
    df_figure["grid_true"] = grid_true
    df_figure["pdf_true"] = pdf_true

    df_figure.to_csv(PATH_RESULTS+f"/plot_posterior_comparison_{alpha}_{EPSILON_STAR:.3}.csv")

# %% [markdown]
# # Same figure from CSV

# %%
for alpha in ALPHAS: 
    EPSILON_STAR = EPSILONS[alpha]
    print("alpha = ", alpha, "epsilon = ", EPSILON_STAR)
    df_figure = pd.read_csv(PATH_RESULTS+f"/plot_posterior_comparison_{alpha}_{EPSILON_STAR:.3}.csv")
    grid_nre = df_figure["grid_nre"]
    pdf_nre = df_figure["pdf_nre"]
    grid_pseudo = df_figure["grid_pseudo"]
    pdf_pseudo = df_figure["pdf_pseudo"]
    grid_nre_corrected = df_figure["grid_nre_corrected"]
    pdf_nre_corrected = df_figure["pdf_nre_corrected"]
    grid_prior = df_figure["grid_prior"]
    pdf_prior = df_figure["pdf_prior"]
    grid_true = df_figure["grid_true"]
    pdf_true = df_figure["pdf_true"]
    
    Z_pseudo = np.trapz(pdf_pseudo, grid_pseudo)
    Z_nre = np.trapz(pdf_nre, grid_nre)
    Z_nre_corrected = np.trapz(pdf_nre_corrected, grid_nre_corrected)
    
    plt.plot(grid_nre, pdf_nre/Z_nre, label = 'NRE Approx. no ABC correction', color = "red")
    plt.plot(grid_pseudo, pdf_pseudo/Z_pseudo, label = "ABC pseudo-post", color = "orange")
    plt.plot(grid_nre_corrected, pdf_nre_corrected/Z_nre_corrected, label = "NRE Approx. with ABC correction", color = "blue", linestyle = "--")

    plt.plot(grid_prior, pdf_prior, label = 'Prior', color = "grey", linestyle = "--")
    plt.plot(grid_true, pdf_true, label = 'True Posterior', color = "green")
    plt.xlim(np.min(grid_true), np.max(grid_true))
    plt.title(f"Posterior comparison for $\epsilon =$ {alpha:.3%} \nNN Accuracy = {TEST_ACCURACY[alpha]:.2%}")
    plt.legend()
    plt.show()
# Out:
# alpha =  1.0 epsilon =  inf
# alpha =  0.99 epsilon =  7436.635
# alpha =  0.9 epsilon =  4276.669
# alpha =  0.75 epsilon =  2836.507
# alpha =  0.5 epsilon =  1579.4377
# alpha =  0.25 epsilon =  690.6506
# alpha =  0.1 epsilon =  210.05894
# alpha =  0.05 epsilon =  70.14465
# alpha =  0.01 epsilon =  3.3594604
# alpha =  0.005 epsilon =  0.8397964
# alpha =  0.001 epsilon =  0.035730872
# alpha =  0.0005 epsilon =  0.007935686
# alpha =  0.0001 epsilon =  0.00035534802

# %% [markdown]
# ## ABC Pseudo posterior

# %%
for alpha in ALPHAS:
    zs, mus, dists, key = ABC_gauss(key, TRUE_DATA, EPSILONS[alpha], 100000)
    label = "$\pi_\epsilon(\\theta\mid x_o) \quad \epsilon = ${:.3%}".format(alpha)
    sns.kdeplot(mus.reshape(-1), label = label)
x = np.linspace(-200, 200, 1000)
plt.plot(x, true_post(TRUE_DATA).pdf(x), label = "$\epsilon =$ 0% (True posterior)", linestyle = "--", color = "green")
plt.plot(x, stats.norm.pdf(x, loc = MU0, scale = SIGMA0), label = "$\epsilon =$ 100.0% (Prior)", linestyle = "--", color = "black")
plt.title("Empiric $\pi_\epsilon(\\theta\mid x_o)$")
plt.legend()
plt.xlim(TRUE_MU-10, TRUE_MU+10)
plt.show()

# %%
prior = stats.norm(loc = MU0, scale = SIGMA0)
for alpha in ALPHAS:
    EPSILON_STAR = EPSILONS[alpha]
    grid_pseudo, pdf_pseudo = find_grid_explorative(lambda x: true_pseudo_post(x, np.mean(TRUE_DATA), EPSILON_STAR, prior), 1000, 1000, MIN_INIT, MAX_INIT)
    label = "$\epsilon = ${:.3%}".format(alpha)
    plt.plot(grid_pseudo, pdf_pseudo/np.trapz(pdf_pseudo, grid_pseudo), label = label)
x = np.linspace(-200, 200, 1000)
plt.plot(x, true_post(TRUE_DATA).pdf(x), label = "$\epsilon =$ 0% (True posterior)", linestyle = "--", color = "green")
plt.plot(x, stats.norm.pdf(x, loc = MU0, scale = SIGMA0), label = "$\epsilon =$ 100.0% (Prior)", linestyle = "--", color = "black")
plt.title("True $\pi_\epsilon(\\theta\mid x_o)$")
plt.legend()
plt.xlim(TRUE_MU-10, TRUE_MU+10)
plt.show()

# %% [markdown]
# ## Decision function

# %%
grid = np.linspace(np.mean(TRUE_DATA)-2, np.mean(TRUE_DATA)+2, 1000)
prior = stats.norm(loc = MU0, scale = SIGMA0)
params = PARAMS[1.]
true_decision = true_decision_z(grid, TRUE_DATA, prior, posterior)
plt.plot(grid, true_decision, color = "green", label = "$\epsilon =$ 100% (True)", lw = 2)
for alpha in ALPHAS:
    params = PARAMS[alpha]
    epsilon = EPSILONS[alpha]
    approx_decision = 1/(1+jnp.exp(-logratio_batch_z(params, grid, TRUE_DATA)))
    label = "$\epsilon = ${:.3%}".format(alpha)
    plt.plot(grid, approx_decision, label = label)
plt.legend()
plt.title("$d_\epsilon(x,\\theta)$")
plt.show()

# %% [markdown]
# ## Likelihood-to-evidence ratio

# %%
grid = np.linspace(np.mean(TRUE_DATA)-1, np.mean(TRUE_DATA)+1, 1000)
prior = stats.norm(loc = MU0, scale = SIGMA0)
params = PARAMS[1.]
true_decision = true_decision_z(grid, TRUE_DATA, prior, posterior)
true_ratio = true_decision/(1-true_decision)
plt.plot(grid, true_ratio, color = "green", label = "True", lw = 2)
for alpha in ALPHAS:
    params = PARAMS[alpha]
    epsilon = EPSILONS[alpha]
    approx_ratio = jnp.exp(logratio_batch_z(params, grid, TRUE_DATA))
    label = "$\epsilon = ${:.3%}".format(alpha)
    plt.plot(grid, approx_ratio, label = label)
plt.legend()
plt.title("$r_\epsilon(x\mid \\theta, x_o)$")
plt.show()

# %% [markdown]
# ## ABC-NRE approximation without correction and normalization

# %%
grid = np.linspace(np.mean(TRUE_DATA)-1, np.mean(TRUE_DATA)+1, 1000)
prior = stats.norm(loc = MU0, scale = SIGMA0)
params = PARAMS[1.]
true_decision = true_decision_z(grid, TRUE_DATA, prior, posterior)
true_ratio = true_decision/(1-true_decision)
plt.plot(grid, true_ratio*prior.pdf(grid), color = "green", label = "True", lw = 2)
for alpha in ALPHAS:
    params = PARAMS[alpha]
    epsilon = EPSILONS[alpha]
    approx_ratio = jnp.exp(logratio_batch_z(params, grid, TRUE_DATA))
    label = "$\epsilon = ${:.3%}".format(alpha)
    plt.plot(grid, approx_ratio*prior.pdf(grid), label = label)
plt.legend()
plt.title("$\hat r_\epsilon(x\mid\\theta, x_o)\cdot \pi(\\theta)$")
plt.show()

# %% [markdown]
# ## ABC-NRE approximation without correction but with normalization

# %%
grid = np.linspace(np.mean(TRUE_DATA)-1, np.mean(TRUE_DATA)+1, 1000)
prior = stats.norm(loc = MU0, scale = SIGMA0)
params = PARAMS[1.]
true_decision = true_decision_z(grid, TRUE_DATA, prior, posterior)
true_ratio = true_decision/(1-true_decision)
true_postt = true_ratio*prior.pdf(grid)
Z_true = np.trapz(true_postt, grid)
print('Z_true =', Z_true)
plt.plot(grid,true_postt/Z_true , color = "green", label = "True", lw = 2)
for alpha in ALPHAS:
    params = PARAMS[alpha]
    epsilon = EPSILONS[alpha]
    
    approx_ratio = jnp.exp(logratio_batch_z(params, grid, TRUE_DATA))
    pseudo = prior.pdf(grid)
    approx = approx_ratio*pseudo
    Z_approx = np.trapz(approx, grid)
    print(f"Z_approx (for epsilon = {epsilon:.2}) = {Z_approx:.2}")
    label = "$\epsilon = ${:.3%}".format(alpha)
    plt.plot(grid,approx/Z_approx, label = label)
plt.plot(grid, prior.pdf(grid), label ="prior", linestyle = "--")
plt.legend()
plt.title("$\hat \pi(\\theta \mid x_o) \propto r_\epsilon(x_o\mid\\theta, x_o)\cdot \pi(\\theta)$")
plt.axhline(0.5, color = "grey", linestyle = "--")
plt.show()
# Out:
# Z_true = 0.9745445938932062
# Z_approx (for epsilon = inf) = 1.0
# Z_approx (for epsilon = 7.4e+03) = 0.92
# Z_approx (for epsilon = 4.3e+03) = 0.83
# Z_approx (for epsilon = 2.8e+03) = 0.84
# Z_approx (for epsilon = 1.6e+03) = 0.52
# Z_approx (for epsilon = 6.9e+02) = 0.25
# Z_approx (for epsilon = 2.1e+02) = 0.1
# Z_approx (for epsilon = 7e+01) = 0.051
# Z_approx (for epsilon = 3.4) = 0.012
# Z_approx (for epsilon = 0.84) = 0.0058
# Z_approx (for epsilon = 0.036) = 0.0055
# Z_approx (for epsilon = 0.0079) = 0.0056
# Z_approx (for epsilon = 0.00036) = 0.0055

# %% [markdown]
# ## ABC-NRE approximation with correction but no normalization

# %%
grid = np.linspace(-100, 200, 10000)
prior = stats.norm(loc = MU0, scale = SIGMA0)
params = PARAMS[1.]
true_decision = true_decision_z(grid, TRUE_DATA, prior, posterior)
true_ratio = true_decision/(1-true_decision)
true_postt = true_ratio*prior.pdf(grid)
plt.plot(grid,true_postt , color = "green", label = "True", lw = 2)
for alpha in ALPHAS:
    params = PARAMS[alpha]
    epsilon = EPSILONS[alpha]
    approx_ratio = jnp.exp(logratio_batch_z(params, grid, TRUE_DATA))
    pseudo = true_pseudo_post(grid, jnp.mean(TRUE_DATA),epsilon, prior)
    approx = approx_ratio*pseudo#/np.trapz(pseudo, grid)
    label = "$\epsilon = ${:.3%}".format(alpha)
    plt.plot(grid,approx, label = label)
plt.plot(grid, prior.pdf(grid), label ="prior", linestyle = "--")

plt.legend()
plt.title("$r_\epsilon(x_o\mid\\theta, x_o)\cdot \pi_\epsilon(\\theta\mid x_o)$")
plt.xlim(grid_true.min(), grid_true.max())
# Out:
# /var/folders/bc/mlt2yzpn2hsg7qskk5s47jy40000gn/T/ipykernel_61983/2353255839.py:23: RuntimeWarning: divide by zero encountered in divide
#   return 1/(1+1/true_ratio_z(mus, z, prior, posterior))
# /var/folders/bc/mlt2yzpn2hsg7qskk5s47jy40000gn/T/ipykernel_61983/2353255839.py:23: RuntimeWarning: overflow encountered in divide
#   return 1/(1+1/true_ratio_z(mus, z, prior, posterior))
# (38.103813, 41.34414)

# %% [markdown]
# ## ABC-NRE approximation with correction and normalization

# %%
grid = np.linspace(np.mean(TRUE_DATA)-1, np.mean(TRUE_DATA)+1, 1000)
prior = stats.norm(loc = MU0, scale = SIGMA0)
params = PARAMS[1.]
true_decision = true_decision_z(grid, TRUE_DATA, prior, posterior)
true_ratio = true_decision/(1-true_decision)
true_postt = true_ratio*prior.pdf(grid)
Z_true = np.trapz(true_postt, grid)
print('Z_true =', Z_true)
plt.plot(grid,true_postt/Z_true , color = "green", label = "True", lw = 2)
for alpha in ALPHAS:
    params = PARAMS[alpha]
    epsilon = EPSILONS[alpha]
    approx_ratio = jnp.exp(logratio_batch_z(params, grid, TRUE_DATA))
    pseudo = true_pseudo_post(grid, jnp.mean(TRUE_DATA),epsilon, prior)
    approx = approx_ratio*pseudo
    Z_approx = np.trapz(approx, grid)
    print(f"Z_approx (for epsilon = {epsilon:.2}) = {Z_approx:.2}")
    plt.plot(grid,approx/Z_approx, label = f"Approx $\epsilon = {epsilon:.2}$", alpha = .5)
plt.plot(grid, prior.pdf(grid), label ="prior", linestyle = "--")
plt.legend()
plt.title("$\hat \pi(\\theta \mid x_o) \propto r_\epsilon(x_o\mid \\theta, x_o)\cdot \pi_\epsilon(\\theta\mid x_o)$")
plt.show()
# Out:
# Z_true = 0.9745445938932062
# Z_approx (for epsilon = inf) = 1.0
# Z_approx (for epsilon = 7.4e+03) = 0.92
# Z_approx (for epsilon = 4.3e+03) = 0.83
# Z_approx (for epsilon = 2.8e+03) = 0.84
# Z_approx (for epsilon = 1.6e+03) = 0.52
# Z_approx (for epsilon = 6.9e+02) = 0.25
# Z_approx (for epsilon = 2.1e+02) = 0.1
# Z_approx (for epsilon = 7e+01) = 0.051
# Z_approx (for epsilon = 3.4) = 0.012
# Z_approx (for epsilon = 0.84) = 0.0049
# Z_approx (for epsilon = 0.036) = 0.001
# Z_approx (for epsilon = 0.0079) = 0.00048
# Z_approx (for epsilon = 0.00036) = 0.0001
