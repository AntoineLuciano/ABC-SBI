# %%
from jax import random, jit, vmap
from functions.simulation import get_dataset, get_epsilon_star
from functions.training import train_loop
from functions.SBC import SBC_epsilon, plot_SBC
import jax.numpy as jnp
import time
import pickle 
import lzma
from jax.scipy.stats import norm


@jit
def prior_simulator(key):
    return random.normal(key, (1,))*SIGMA0 + MU0

@jit
def data_simulator(key, theta):
    return (random.normal(key, (N_DATA,))*SIGMA + theta).astype(float)

@jit
def discrepancy(y, y_true):
    return (jnp.mean(y) - jnp.mean(y_true))**2

# %%
key = random.PRNGKey(0)
 
MU0 = 0.
SIGMA = 1.
MODEL_ARGS = [SIGMA]
N_DATA = 100
N_POINTS_TRAIN = 1000000
N_POINTS_TEST = 100000
N_POINTS_EPS = 10000
sim_args = None
N_EPOCHS = 100
LEARNING_RATE = 0.001
PATIENCE = 7
COOLDOWN = 0
FACTOR = .5
RTOL = 1e-4  
ACCUMULATION_SIZE = 200
LEARNING_RATE_MIN = 1e-6
BATCH_SIZE = 256
NUM_BATCH = 1024
NUM_CLASSES = 2
HIDDEN_SIZE = 256
NUM_LAYERS = 7
WDECAY = .001
N_GRID_FINAL = 10000
N_GRID_EXPLO = 1000
MINN, MAXX = -50.,50. 
L = 127
N_SBC = (L+1)*20
# Out:
# SIGMA0 = 10.0

# %%
key = random.PRNGKey(0)
 
MU0 = 0.
SIGMA = 1.
MODEL_ARGS = [SIGMA]
N_DATA = 100
N_POINTS_TRAIN = 1000000
N_POINTS_TEST = 100000
N_POINTS_EPS = 10000
sim_args = None
N_EPOCHS = 100
LEARNING_RATE = 0.001
PATIENCE = 7
COOLDOWN = 0
FACTOR = .5
RTOL = 1e-4  
ACCUMULATION_SIZE = 200
LEARNING_RATE_MIN = 1e-6
BATCH_SIZE = 256
NUM_BATCH = 1024
NUM_CLASSES = 2
HIDDEN_SIZE = 256
NUM_LAYERS = 7
WDECAY = .001
N_GRID_FINAL = 10000
N_GRID_EXPLO = 1000
MINN, MAXX = -50.,50. 
L = 127
N_SBC = (L+1)*20



SIGMAS0 = [5*SIGMA, 10*SIGMA, 20*SIGMA]

for SIGMA0 in SIGMAS0:
    TRUE_MUS = [.1*SIGMA0, .5*SIGMA0, SIGMA0, 1.5*SIGMA0]
    PRIOR_ARGS = [MU0, SIGMA0]
    PRIOR_LOGPDF = lambda x: norm.logpdf(x, loc = MU0, scale = SIGMA0)

    for TRUE_MU in TRUE_MUS:
        EPSILON_STAR = jnp.inf
        key, subkey = random.split(key)
        TRUE_DATA = data_simulator(subkey, TRUE_MU)
        for ACCEPT_RATE in [1., .999, .99, .975, .95, .925, .9, .8,.75, .7, .6, .5]:
            print("\n\n--------------------")
            print("SIGMA0 = {}, TRUE_MU = {}, ACCEPT_RATE = {}".format(SIGMA0, TRUE_MU, ACCEPT_RATE))
            print("--------------------\n\n")
                    
            
            time_eps = time.time()
            print("Selection of epsilon star...")
            EPSILON_STAR, key = get_epsilon_star(key, ACCEPT_RATE, N_POINTS_EPS, prior_simulator, data_simulator, discrepancy, TRUE_DATA, quantile_rate = .99, epsilon = EPSILON_STAR)
            print('Time to select epsilon star: {:.2f}s\n'.format(time.time()-time_eps))

            print("Simulations of the testing dataset...")
            time_sim = time.time()
            X_test, y_test, key = get_dataset(key, N_POINTS_TEST, prior_simulator, data_simulator, discrepancy, EPSILON_STAR, TRUE_DATA)
            print('Time to simulate the testing dataset: {:.2f}s\n'.format(time.time()-time_sim))

            # print("Simulations of the training dataset...")
            # time_sim = time.time()
            # X_train, y_train, key = get_dataset(key, N_POINTS_TRAIN, prior_simulator, data_simulator, discrepancy, EPSILON_STAR, TRUE_DATA)
            # print('Time to simulate the training dataset: {:.2f}s\n'.format(time.time()-time_sim))


            print("Training the neural network...")
            time_nn = time.time()
            params, train_accuracy, train_losses, test_accuracy, test_losses, key = train_loop(key, N_EPOCHS, NUM_LAYERS, HIDDEN_SIZE, NUM_CLASSES, BATCH_SIZE, NUM_BATCH, LEARNING_RATE, WDECAY, PATIENCE, COOLDOWN, FACTOR, RTOL, ACCUMULATION_SIZE, LEARNING_RATE_MIN, prior_simulator, data_simulator, discrepancy, true_data = TRUE_DATA, X_train = None, y_train = None, X_test = X_test, y_test =  y_test, N_POINTS_TRAIN = N_POINTS_TRAIN, N_POINTS_TEST = N_POINTS_TEST, epsilon = EPSILON_STAR, verbose = True)
            print('Time to train the neural network: {:.2f}s\n'.format(time.time()-time_nn))


            print("Simulation Based Calibration...")
            time_sbc = time.time()

            ranks, thetas_tilde, thetas, key = SBC_epsilon(key = key, N_SBC = N_SBC, L = L, params = params, epsilon = EPSILON_STAR, true_data = TRUE_DATA, prior_simulator = prior_simulator, prior_logpdf = PRIOR_LOGPDF, data_simulator = data_simulator, discrepancy = discrepancy, n_grid_explo = N_GRID_EXPLO, n_grid_final = N_GRID_FINAL, minn = MINN, maxx = MAXX)

            print('Time to perform SBC: {:.2f}s\n'.format(time.time()-time_sbc))


            pickle_dico = {"ranks": ranks, "thetas_tilde": thetas_tilde, "thetas": thetas, "epsilon":EPSILON_STAR, "KEY":key, "N_SBC":N_SBC, "L":L, "N_GRID_EXPLO": N_GRID_EXPLO, 'N_GRID_FINAL': N_GRID_FINAL,"TRUE_DATA": TRUE_DATA, "TRUE_THETA": TRUE_MU, "params": params, "train_accuracy":train_accuracy, "test_accuracy":test_accuracy, "MODEL_ARGS":MODEL_ARGS, "PRIOR_ARGS":PRIOR_ARGS, "N_POINTS_TRAIN":N_POINTS_TRAIN, "N_POINTS_TEST":N_POINTS_TEST, "N_DATA":N_DATA, "N_EPOCHS":N_EPOCHS, "LEARNING_RATE":LEARNING_RATE, "PATIENCE":PATIENCE, "COOLDOWN":COOLDOWN, "FACTOR":FACTOR, "RTOL":RTOL, "ACCUMULATION_SIZE":ACCUMULATION_SIZE, "LEARNING_RATE_MIN":LEARNING_RATE_MIN, "BATCH_SIZE":BATCH_SIZE, "NUM_BATCH":NUM_BATCH, "NUM_CLASSES":NUM_CLASSES, "HIDDEN_SIZE":HIDDEN_SIZE, "NUM_LAYERS":NUM_LAYERS, "WDECAY":WDECAY}

            name = "./new_new_pickle/Gaussian_notsort_meandist/Gaussian_notsort_meandist_sigma_{}_sigma0_{}_mu_{}_acc_{:.3}_eps_{:.5}.xz".format(SIGMA, SIGMA0, TRUE_MU, ACCEPT_RATE, EPSILON_STAR)

            with lzma.open(name, "wb") as f:
                pickle.dump(pickle_dico, f)
            print("Data saved in ", name)

            title = "Normal w/ known std\nsigma = {}, sigma0 = {} mu = {}\nalpha = {:.2%}, eps = {:.3} accuracy = {:.2%}".format(SIGMA, SIGMA0, TRUE_MU, ACCEPT_RATE, EPSILON_STAR, test_accuracy[-1])

            name_plot = "./new_new_fig/Gaussian_notsort_meandist/Gaussian_notsort_meandist_sigma_{}_sigma0_{}_mu_{}_acc_{:.3}_eps_{:.5}.png".format(SIGMA, SIGMA0, TRUE_MU, ACCEPT_RATE, EPSILON_STAR)
            plot_SBC(ranks, L, B = 16, title = title, save_name = name_plot)
            print("Plot saved in ", name_plot)
            
            print("\n\n--------------------")
            print("ITERATION (ACC = {}) DONE IN {} SECONDS!".format(ACCEPT_RATE, time.time()-time_eps))
            print("--------------------\n\n")
# Out:
# --------------------
# SIGMA0 = 5.0, TRUE_MU = 0.5, ACCEPT_RATE = 1.0
# --------------------
#
#
# Selection of epsilon star...
# Distances: min =  5.0774634e-07 max =  351.43564 mean =  25.633043 std =  35.61118
# Time to select epsilon star: 0.74s
#
# Simulations of the testing dataset...
# Time to simulate the testing dataset: 0.82s
#
# Simulations of the training dataset...
# Time to simulate the training dataset: 1.59s
#
# Training the neural network...
# Initial accuracy: 50.31%, Initial test accuracy: 50.28%
# Training for 100 epochs...
# Epoch 1/100, mean train accuracy: 93.18%, mean test accuracy: 95.84%, lr scale: 1.0 in 8.70 sec
# Epoch 2/100, mean train accuracy: 89.55%, mean test accuracy: 89.57%, lr scale: 1.0 in 7.94 sec
# Epoch 3/100, mean train accuracy: 95.59%, mean test accuracy: 97.60%, lr scale: 1.0 in 7.95 sec
# Epoch 4/100, mean train accuracy: 96.27%, mean test accuracy: 97.31%, lr scale: 1.0 in 7.90 sec
# Epoch 5/100, mean train accuracy: 82.19%, mean test accuracy: 97.03%, lr scale: 1.0 in 8.02 sec
# Epoch 6/100, mean train accuracy: 96.94%, mean test accuracy: 97.49%, lr scale: 0.5 in 8.12 sec
# Epoch 7/100, mean train accuracy: 97.33%, mean test accuracy: 97.65%, lr scale: 0.5 in 8.08 sec
# Epoch 8/100, mean train accuracy: 97.38%, mean test accuracy: 97.81%, lr scale: 0.25 in 8.38 sec
# Epoch 9/100, mean train accuracy: 97.73%, mean test accuracy: 97.48%, lr scale: 0.25 in 8.30 sec
# Epoch 10/100, mean train accuracy: 97.70%, mean test accuracy: 97.94%, lr scale: 0.125 in 8.60 sec
# Epoch 11/100, mean train accuracy: 97.94%, mean test accuracy: 97.87%, lr scale: 0.125 in 8.17 sec
# Epoch 12/100, mean train accuracy: 97.91%, mean test accuracy: 97.98%, lr scale: 0.0625 in 7.96 sec
# Epoch 13/100, mean train accuracy: 98.00%, mean test accuracy: 98.01%, lr scale: 0.0625 in 7.96 sec
# Epoch 14/100, mean train accuracy: 97.92%, mean test accuracy: 97.83%, lr scale: 0.0625 in 8.31 sec
# Epoch 15/100, mean train accuracy: 97.97%, mean test accuracy: 97.93%, lr scale: 0.0625 in 7.92 sec
# Epoch 16/100, mean train accuracy: 97.99%, mean test accuracy: 98.00%, lr scale: 0.03125 in 7.89 sec
# Epoch 17/100, mean train accuracy: 98.03%, mean test accuracy: 97.93%, lr scale: 0.03125 in 7.94 sec
# Epoch 18/100, mean train accuracy: 98.04%, mean test accuracy: 98.06%, lr scale: 0.015625 in 7.86 sec
# Epoch 19/100, mean train accuracy: 98.04%, mean test accuracy: 97.98%, lr scale: 0.015625 in 8.59 sec
# Epoch 20/100, mean train accuracy: 98.08%, mean test accuracy: 98.03%, lr scale: 0.015625 in 7.72 sec
# Epoch 21/100, mean train accuracy: 98.03%, mean test accuracy: 98.06%, lr scale: 0.0078125 in 7.69 sec
# Epoch 22/100, mean train accuracy: 98.11%, mean test accuracy: 98.04%, lr scale: 0.0078125 in 7.57 sec
# Epoch 23/100, mean train accuracy: 98.06%, mean test accuracy: 98.07%, lr scale: 0.00390625 in 7.62 sec
# Epoch 24/100, mean train accuracy: 98.13%, mean test accuracy: 98.06%, lr scale: 0.001953125 in 7.76 sec
# Epoch 25/100, mean train accuracy: 98.11%, mean test accuracy: 98.06%, lr scale: 0.0009765625 in 7.68 sec
# Learning rate reached 1.00E-06, stopping training
# Time to train the neural network: 211.77s
#
# Simulation Based Calibration...
#   0%|          | 0/2560 [00:00<?, ?it/s]
# Time to perform SBC: 154.23s
#
# Data saved in  ./new_new_pickle/Gaussian_notsort_meandist/Gaussian_notsort_meandist_sigma_1.0_sigma0_5.0_mu_0.5_acc_1.0_eps_inf.xz
# Plot saved in  ./new_new_fig/Gaussian_notsort_meandist/Gaussian_notsort_meandist_sigma_1.0_sigma0_5.0_mu_0.5_acc_1.0_eps_inf.png
#
#
# --------------------
# ITERATION (ACC = 1.0) DONE IN 370.33327531814575 SECONDS!
# --------------------
#
#
#
#
# --------------------
# SIGMA0 = 5.0, TRUE_MU = 0.5, ACCEPT_RATE = 0.999
# --------------------
#
#
# Selection of epsilon star...
# Distances: min =  3.899477e-08 max =  359.39096 mean =  25.146002 std =  35.12294
# epsilon:  162.3310089111328 acceptance rate:  0.9996
# epsilon:  136.60726928710938 acceptance rate:  0.99909997
# epsilon:  121.49668884277344 acceptance rate:  0.9995
# epsilon:  108.10960388183594 acceptance rate:  0.99939996
# epsilon:  98.85842895507812 acceptance rate:  0.99829996
# Time to select epsilon star: 3.25s
#
# Simulations of the testing dataset...
# Time to simulate the testing dataset: 0.95s
#
# Simulations of the training dataset...
# Time to simulate the training dataset: 3.74s
#
# Training the neural network...
# Initial accuracy: 50.20%, Initial test accuracy: 50.17%
# Training for 100 epochs...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 68
#      66 print("Training the neural network...")
#      67 time_nn = time.time()
# ---> 68 params, train_accuracy, train_losses, test_accuracy, test_losses, key = train_loop(key, N_EPOCHS, NUM_LAYERS, HIDDEN_SIZE, NUM_CLASSES, BATCH_SIZE, NUM_BATCH, LEARNING_RATE, WDECAY, PATIENCE, COOLDOWN, FACTOR, RTOL, ACCUMULATION_SIZE, LEARNING_RATE_MIN, prior_simulator, data_simulator, discrepancy, true_data = TRUE_DATA, X_train = None, y_train = None, X_test = X_test, y_test =  y_test, N_POINTS_TRAIN = N_POINTS_TRAIN, N_POINTS_TEST = N_POINTS_TEST, epsilon = EPSILON_STAR, verbose = True)
#      69 print('Time to train the neural network: {:.2f}s\n'.format(time.time()-time_nn))
#      72 print("Simulation Based Calibration...")
#
# File ~/Documents/Recherche/new ABC-NRE/functions/training.py:109, in train_loop(key, num_epoch_max, num_layers, hidden_size, num_classes, batch_size, num_batch, learning_rate, wdecay, patience, cooldown, factor, rtol, accumulation_size, learning_rate_min, prior_simulator, data_simulator, discrepancy, true_data, X_train, y_train, X_test, y_test, N_POINTS_TRAIN, N_POINTS_TEST, epsilon, verbose)
#     107 key, subkey = random.split(key)
#     108 for inputs_batch, labels_batch in get_train_batches(X_train, y_train, batch_size, num_batch, subkey, true_data):
# --> 109     params, opt_state, train_loss, train_aux = train_step(
#     110         params, opt_state, inputs_batch, labels_batch
#     111     )
#     112     train_accuracy_epoch.append(train_aux["accuracy"])
#     113     train_losses_epoch.append(train_loss)
#
# File <string>:1, in <lambda>(_cls, count, mu, nu)
#
# KeyboardInterrupt:

# %%
for ACCEPT_RATE in [1., .999, .99, .975, .95, .925, .9, .8,.75, .7, .6, .5]:
    print("\n\n--------------------")
    print("ACCEPT RATE: ", ACCEPT_RATE)
    print("--------------------\n\n")
    
    
    time_eps = time.time()
    print("Selection of epsilon star...")
    EPSILON_STAR, key = get_epsilon_star(key, ACCEPT_RATE, N_POINTS_EPS, prior_simulator, data_simulator, discrepancy, TRUE_DATA, quantile_rate = .99, epsilon = EPSILON_STAR)
    print('Time to select epsilon star: {:.2f}s\n'.format(time.time()-time_eps))

    print("Simulations of the testing dataset...")
    time_sim = time.time()
    X_test, y_test, key = get_dataset(key, N_POINTS_TEST, prior_simulator, data_simulator, discrepancy, EPSILON_STAR, TRUE_DATA)
    print('Time to simulate the testing dataset: {:.2f}s\n'.format(time.time()-time_sim))

    print("Simulations of the training dataset...")
    time_sim = time.time()
    X_train, y_train, key = get_dataset(key, N_POINTS_TRAIN, prior_simulator, data_simulator, discrepancy, EPSILON_STAR, TRUE_DATA)
    print('Time to simulate the training dataset: {:.2f}s\n'.format(time.time()-time_sim))


    print("Training the neural network...")
    time_nn = time.time()
    params, train_accuracy, train_losses, test_accuracy, test_losses, key = train_loop(key, N_EPOCHS, NUM_LAYERS, HIDDEN_SIZE, NUM_CLASSES, BATCH_SIZE, NUM_BATCH, LEARNING_RATE, WDECAY, PATIENCE, COOLDOWN, FACTOR, RTOL, ACCUMULATION_SIZE, LEARNING_RATE_MIN, prior_simulator, data_simulator, discrepancy, true_data = TRUE_DATA, X_train = None, y_train = None, X_test = X_test, y_test =  y_test, N_POINTS_TRAIN = N_POINTS_TRAIN, N_POINTS_TEST = N_POINTS_TEST, epsilon = EPSILON_STAR, verbose = True)
    print('Time to train the neural network: {:.2f}s\n'.format(time.time()-time_nn))


    print("Simulation Based Calibration...")
    time_sbc = time.time()

    ranks, thetas_tilde, thetas, key = SBC_epsilon(key = key, N_SBC = N_SBC, L = L, params = params, epsilon = EPSILON_STAR, true_data = TRUE_DATA, prior_simulator = prior_simulator, prior_logpdf = PRIOR_LOGPDF, data_simulator = data_simulator, discrepancy = discrepancy, n_grid_explo = N_GRID_EXPLO, n_grid_final = N_GRID_FINAL, minn = MINN, maxx = MAXX)

    print('Time to perform SBC: {:.2f}s\n'.format(time.time()-time_sbc))


    pickle_dico = {"ranks": ranks, "thetas_tilde": thetas_tilde, "thetas": thetas, "epsilon":EPSILON_STAR, "KEY":key, "N_SBC":N_SBC, "L":L, "N_GRID_EXPLO": N_GRID_EXPLO, 'N_GRID_FINAL': N_GRID_FINAL,"TRUE_DATA": TRUE_DATA, "TRUE_THETA": TRUE_MU, "params": params, "train_accuracy":train_accuracy, "test_accuracy":test_accuracy, "MODEL_ARGS":MODEL_ARGS, "PRIOR_ARGS":PRIOR_ARGS, "N_POINTS_TRAIN":N_POINTS_TRAIN, "N_POINTS_TEST":N_POINTS_TEST, "N_DATA":N_DATA, "N_EPOCHS":N_EPOCHS, "LEARNING_RATE":LEARNING_RATE, "PATIENCE":PATIENCE, "COOLDOWN":COOLDOWN, "FACTOR":FACTOR, "RTOL":RTOL, "ACCUMULATION_SIZE":ACCUMULATION_SIZE, "LEARNING_RATE_MIN":LEARNING_RATE_MIN, "BATCH_SIZE":BATCH_SIZE, "NUM_BATCH":NUM_BATCH, "NUM_CLASSES":NUM_CLASSES, "HIDDEN_SIZE":HIDDEN_SIZE, "NUM_LAYERS":NUM_LAYERS, "WDECAY":WDECAY}

    name = "./new_new_pickle/Gaussian_notsort_meandist_sigma_{}_sigma0_{}_mu_{}_acc_{:.3}_eps_{:.5}.xz".format(SIGMA, SIGMA0, TRUE_MU, ACCEPT_RATE, EPSILON_STAR)

    with lzma.open(name, "wb") as f:
        pickle.dump(pickle_dico, f)
    print("Data saved in ", name)

    title = "Normal w/ known std\nsigma = {}, sigma0 = {} mu = {}\nalpha = {:.2%}, eps = {:.3} accuracy = {:.2%}".format(SIGMA, SIGMA0, TRUE_MU, ACCEPT_RATE, EPSILON_STAR, test_accuracy[-1])

    name_plot = "./new_new_fig/Gaussian_notsort_meandist_sigma_{}_sigma0_{}_mu_{}_acc_{:.3}_eps_{:.5}.png".format(SIGMA, SIGMA0, TRUE_MU, ACCEPT_RATE, EPSILON_STAR)
    plot_SBC(ranks, L, B = 16, title = title, save_name = name_plot)
    print("Plot saved in ", name_plot)
    
    print("\n\n--------------------")
    print("ITERATION (ACC = {}) DONE IN {} SECONDS!".format(ACCEPT_RATE, time.time()-time_eps))
    print("--------------------\n\n")
# Out:
# --------------------
# ACCEPT RATE:  1.0
# --------------------
#
#
# Selection of epsilon star...
# Time to select epsilon star: 0.06s
#
# Simulations of the testing dataset...
# Time to simulate the testing dataset: 0.24s
#
# Simulations of the training dataset...
# Time to simulate the training dataset: 2.90s
#
# Training the neural network...
# Initial accuracy: 49.35%, Initial test accuracy: 49.36%
# Training for 100 epochs...
# Epoch 1/100, mean train accuracy: 92.65%, mean test accuracy: 97.83%, lr scale: 1.0 in 8.89 sec
# Epoch 2/100, mean train accuracy: 95.12%, mean test accuracy: 97.48%, lr scale: 1.0 in 8.34 sec
# Epoch 3/100, mean train accuracy: 95.02%, mean test accuracy: 98.29%, lr scale: 1.0 in 8.78 sec
# Epoch 4/100, mean train accuracy: 96.50%, mean test accuracy: 94.01%, lr scale: 1.0 in 9.04 sec
# Epoch 5/100, mean train accuracy: 95.52%, mean test accuracy: 98.55%, lr scale: 0.5 in 9.14 sec
# Epoch 6/100, mean train accuracy: 98.30%, mean test accuracy: 98.64%, lr scale: 0.5 in 9.14 sec
# Epoch 7/100, mean train accuracy: 98.25%, mean test accuracy: 98.61%, lr scale: 0.25 in 9.26 sec
# Epoch 8/100, mean train accuracy: 98.42%, mean test accuracy: 98.24%, lr scale: 0.25 in 8.51 sec
# Epoch 9/100, mean train accuracy: 98.57%, mean test accuracy: 98.72%, lr scale: 0.125 in 8.97 sec
# Epoch 10/100, mean train accuracy: 98.69%, mean test accuracy: 98.69%, lr scale: 0.125 in 9.02 sec
# Epoch 11/100, mean train accuracy: 98.66%, mean test accuracy: 98.77%, lr scale: 0.0625 in 8.93 sec
# Epoch 12/100, mean train accuracy: 98.76%, mean test accuracy: 98.82%, lr scale: 0.0625 in 9.72 sec
# Epoch 13/100, mean train accuracy: 98.71%, mean test accuracy: 98.82%, lr scale: 0.03125 in 9.15 sec
# Epoch 14/100, mean train accuracy: 98.77%, mean test accuracy: 98.81%, lr scale: 0.03125 in 9.22 sec
# Epoch 15/100, mean train accuracy: 98.79%, mean test accuracy: 98.83%, lr scale: 0.03125 in 9.32 sec
# Epoch 16/100, mean train accuracy: 98.76%, mean test accuracy: 98.84%, lr scale: 0.015625 in 9.34 sec
# Epoch 17/100, mean train accuracy: 98.82%, mean test accuracy: 98.76%, lr scale: 0.015625 in 9.27 sec
# Epoch 18/100, mean train accuracy: 98.82%, mean test accuracy: 98.83%, lr scale: 0.0078125 in 9.30 sec
# Epoch 19/100, mean train accuracy: 98.79%, mean test accuracy: 98.85%, lr scale: 0.0078125 in 9.46 sec
# Epoch 20/100, mean train accuracy: 98.83%, mean test accuracy: 98.85%, lr scale: 0.00390625 in 9.29 sec
# Epoch 21/100, mean train accuracy: 98.81%, mean test accuracy: 98.86%, lr scale: 0.001953125 in 9.70 sec
# Epoch 22/100, mean train accuracy: 98.84%, mean test accuracy: 98.86%, lr scale: 0.001953125 in 9.15 sec
# Epoch 23/100, mean train accuracy: 98.85%, mean test accuracy: 98.86%, lr scale: 0.0009765625 in 9.08 sec
# Learning rate reached 1.00E-06, stopping training
# Time to train the neural network: 222.73s
#
# Simulation Based Calibration...
#   0%|          | 0/2560 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 32
#      29 print("Simulation Based Calibration...")
#      30 time_sbc = time.time()
# ---> 32 ranks, thetas_tilde, thetas, key = SBC_epsilon(key = key, N_SBC = N_SBC, L = L, params = params, epsilon = EPSILON_STAR, true_data = TRUE_DATA, prior_simulator = prior_simulator, prior_logpdf = PRIOR_LOGPDF, data_simulator = data_simulator, discrepancy = discrepancy, n_grid_explo = N_GRID_EXPLO, n_grid_final = N_GRID_FINAL, minn = MINN, maxx = MAXX)
#      34 print('Time to perform SBC: {:.2f}s\n'.format(time.time()-time_sbc))
#      37 pickle_dico = {"ranks": ranks, "thetas_tilde": thetas_tilde, "thetas": thetas, "epsilon":EPSILON_STAR, "KEY":key, "N_SBC":N_SBC, "L":L, "N_GRID_EXPLO": N_GRID_EXPLO, 'N_GRID_FINAL': N_GRID_FINAL,"TRUE_DATA": TRUE_DATA, "TRUE_THETA": TRUE_MU, "params": params, "train_accuracy":train_accuracy, "test_accuracy":test_accuracy, "MODEL_ARGS":MODEL_ARGS, "PRIOR_ARGS":PRIOR_ARGS, "N_POINTS_TRAIN":N_POINTS_TRAIN, "N_POINTS_TEST":N_POINTS_TEST, "N_DATA":N_DATA, "N_EPOCHS":N_EPOCHS, "LEARNING_RATE":LEARNING_RATE, "PATIENCE":PATIENCE, "COOLDOWN":COOLDOWN, "FACTOR":FACTOR, "RTOL":RTOL, "ACCUMULATION_SIZE":ACCUMULATION_SIZE, "LEARNING_RATE_MIN":LEARNING_RATE_MIN, "BATCH_SIZE":BATCH_SIZE, "NUM_BATCH":NUM_BATCH, "NUM_CLASSES":NUM_CLASSES, "HIDDEN_SIZE":HIDDEN_SIZE, "NUM_LAYERS":NUM_LAYERS, "WDECAY":WDECAY}
#
# File ~/Documents/Recherche/new ABC-NRE/functions/SBC.py:121, in SBC_epsilon(key, N_SBC, L, params, epsilon, true_data, prior_simulator, prior_logpdf, data_simulator, discrepancy, n_grid_explo, n_grid_final, minn, maxx, X)
#     119 thetas = jnp.zeros((N_SBC, L))
#     120 for i in tqdm(range(N_SBC), mininterval= N_SBC//20):
# --> 121     grid, pdf_value = find_grid_explorative(lambda x: post_pdf_z(params, x, datas[i], prior_logpdf), n_grid_explo, n_grid_final, minn, maxx)
#     122     grids = grids.at[i].set(grid)
#     123     pdf_values = pdf_values.at[i].set(pdf_value)
#
# File ~/Documents/Recherche/new ABC-NRE/functions/SBC.py:104, in find_grid_explorative(func, n_eval_explo, n_eval_final, min_grid, max_grid, threshold_factor, max_expansion, expansion_factor)
#     101     min_grid_opt, max_grid_opt = min_grid, max_grid
#     103 grid_opt = jnp.linspace(min_grid_opt, max_grid_opt, n_eval_final)
# --> 104 pdf_values = func(grid_opt)
#     106 return grid_opt, pdf_values
#
# File ~/Documents/Recherche/new ABC-NRE/functions/SBC.py:121, in SBC_epsilon.<locals>.<lambda>(x)
#     119 thetas = jnp.zeros((N_SBC, L))
#     120 for i in tqdm(range(N_SBC), mininterval= N_SBC//20):
# --> 121     grid, pdf_value = find_grid_explorative(lambda x: post_pdf_z(params, x, datas[i], prior_logpdf), n_grid_explo, n_grid_final, minn, maxx)
#     122     grids = grids.at[i].set(grid)
#     123     pdf_values = pdf_values.at[i].set(pdf_value)
#
# File ~/Documents/Recherche/new ABC-NRE/functions/SBC.py:57, in post_pdf_z(params, mus, z, prior_logpdf)
#      56 def post_pdf_z(params, mus, z, prior_logpdf):
# ---> 57     return jnp.exp(prior_logpdf(mus)+logratio_batch_z(params, mus, z))
#
#     [... skipping hidden 1 frame]
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/api.py:1225, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1222 axis_size_ = (axis_size if axis_size is not None else
#    1223               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
#    1224 try:
# -> 1225   out_flat = batching.batch(
#    1226       flat_fun, axis_name, axis_size_, in_axes_flat,
#    1227       lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1228       spmd_axis_name=spmd_axis_name
#    1229   ).call_wrapped(*args_flat)
#    1230 except batching.SpecMatchError as e:
#    1231   out_axes_flat = flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
#     [... skipping hidden 1 frame]
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/pjit.py:332, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     330 @api_boundary
#     331 def cache_miss(*args, **kwargs):
# --> 332   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     333       fun, jit_info, *args, **kwargs)
#     334   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     335   pgle_profiler = _read_pgle_profiler(jaxpr)
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/pjit.py:190, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     187   args_flat = [*init_states, *args_flat]
#     189 try:
# --> 190   out_flat = pjit_p.bind(*args_flat, **p.params)
#     191 except pxla.DeviceAssignmentMismatchError as e:
#     192   fails, = e.args
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/core.py:2739, in AxisPrimitive.bind(self, *args, **params)
#    2735 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2736                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2737 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2738              else axis_main.with_cur_sublevel())
# -> 2739 return self.bind_with_trace(top_trace, args, params)
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/core.py:433, in Primitive.bind_with_trace(self, trace, args, params)
#     431 def bind_with_trace(self, trace, args, params):
#     432   with pop_level(trace.level):
# --> 433     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     434   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:438, in BatchTrace.process_primitive(self, primitive, tracers, params)
#     436   frame = self.get_frame(vals_in, dims_in)
#     437   batched_primitive = self.get_primitive_batcher(primitive, frame)
# --> 438   val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     439 src = source_info_util.current()
#     440 if primitive.multiple_results:
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/pjit.py:1973, in _pjit_batcher(spmd_axis_name, axis_size, axis_name, main_type, vals_in, dims_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline)
#    1968 if not (all(l is None for l in in_layouts) and
#    1969         all(l is None for l in out_layouts)):
#    1970   raise NotImplementedError(
#    1971       'Concrete layouts are not supported for vmap(jit).')
# -> 1973 vals_out = pjit_p.bind(
#    1974   *vals_in,
#    1975   jaxpr=new_jaxpr,
#    1976   in_shardings=in_shardings,
#    1977   out_shardings=out_shardings,
#    1978   in_layouts=in_layouts,
#    1979   out_layouts=out_layouts,
#    1980   resource_env=resource_env,
#    1981   donated_invars=donated_invars,
#    1982   name=name,
#    1983   keep_unused=keep_unused,
#    1984   inline=inline)
#    1986 resolved_axes_out = batching.resolve_ragged_axes_against_inputs_outputs(
#    1987     vals_in, vals_out, axes_out)
#    1988 return vals_out, resolved_axes_out
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/core.py:2739, in AxisPrimitive.bind(self, *args, **params)
#    2735 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2736                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2737 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2738              else axis_main.with_cur_sublevel())
# -> 2739 return self.bind_with_trace(top_trace, args, params)
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/core.py:433, in Primitive.bind_with_trace(self, trace, args, params)
#     431 def bind_with_trace(self, trace, args, params):
#     432   with pop_level(trace.level):
# --> 433     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     434   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/core.py:939, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     937   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     938 else:
# --> 939   return primitive.impl(*tracers, **params)
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/pjit.py:1730, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1727 donated_argnums = [i for i, d in enumerate(donated_invars) if d]
#    1728 has_explicit_sharding = _pjit_explicit_sharding(
#    1729     in_shardings, out_shardings, None, None)
# -> 1730 return xc._xla.pjit(
#    1731     name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1732     tree_util.dispatch_registry,
#    1733     lambda x, sharding: pxla.shard_args([sharding], [x])[0],
#    1734     _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# KeyboardInterrupt:
