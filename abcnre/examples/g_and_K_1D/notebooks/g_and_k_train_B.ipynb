# %% [markdown]
# # TRAIN

# %%
from pathlib import Path
from abcnre.simulation import ABCSimulator
from abcnre.simulation.models import create_model_from_dict, get_example_model_configs
import yaml
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
# %load_ext autoreload
# %autoreload 2

current_dir = Path().resolve() 
parent_dir = current_dir.parent    
results_dir = parent_dir / "results" 

print("--- Step 1: Load model and create simulator ---")
model_name = "g_and_k_default"
model_config = get_example_model_configs(model_name)
model_config["model_args"]["parameter_of_interest"] = "B"  # Set marginal of interest to B
marginal_of_interest = 1


model = create_model_from_dict(model_config)
print(f"Model loaded: {model}")


simulator = ABCSimulator(model=model)
# Out:
# INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/Users/antoineluciano/.pyenv/versions/3.10.13/lib/libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/antoineluciano/.pyenv/versions/3.10.13/lib/libtpu.so' (no such file), '/opt/homebrew/lib/libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/libtpu.so' (no such file), '/Users/antoineluciano/.pyenv/versions/3.10.13/lib/libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/antoineluciano/.pyenv/versions/3.10.13/lib/libtpu.so' (no such file), '/opt/homebrew/lib/libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/libtpu.so' (no such file), '/Users/antoineluciano/.pyenv/versions/3.10.13/lib/libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/antoineluciano/.pyenv/versions/3.10.13/lib/libtpu.so' (no such file), '/opt/homebrew/lib/libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file), '/usr/local/lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache)
# --- Step 1: Load model and create simulator ---
# Model loaded: GAndKModel({'model_type': 'GAndKModel', 'model_class': 'GAndKModel', 'model_args': {'prior_bounds': {'A': [0.0, 5.0], 'B': [0.0010000000474974513, 5.0], 'g': [0.0, 5.0], 'k': [0.0, 5.0]}, 'dim': 1, 'n_obs': 100, 'parameter_of_interest': 'B'}})
# DEBUG: Summary statistics for data = (100, 1)
# INFO:abcnre.simulation.simulator:Created temporary observed data for prior sampling mode

# %%
print("--- Step 1.5 : Learn Summary Stats (Optional) ---")

import jax
from abcnre.training import get_nn_config
key = jax.random.PRNGKey(1)
key, subkey_learn = jax.random.split(key)


regressor_config = get_nn_config(network_name="deepset",
                          network_size = "large",
                          training_size = "extended",
                          task_type = "regressor",
                          lr_scheduler_name = "reduce_on_plateau",
                          lr_scheduler_variant = "default",
                          stopping_rules_variant = "balanced",
                          experiment_name = None, 
                          output_dim= 4)


simulator.train_summary_network(subkey_learn, regressor_config)

key, subkey_check = jax.random.split(key)
simulator.check_summary_stats_correlation(
    subkey_check,
    n_samples=10000)
# Out:
# INFO:abcnre.training.config:Set output_dim=4 for regressor
# INFO:abcnre.training.config:Using custom lr_scheduler: reduce_on_plateau_default
# INFO:abcnre.training.config:Using stopping rules: balanced
# INFO:abcnre.training.config:Created NN config: regressor_deepset_large_extended (task: regressor)
# --- Step 1.5 : Learn Summary Stats (Optional) ---
# INFO:abcnre.training.components.metrics:Configuration Summary:
# INFO:abcnre.training.components.metrics:   Task: regressor
# INFO:abcnre.training.components.metrics:   Network: DeepSet
# INFO:abcnre.training.components.metrics:   Optimizer: adamw
# INFO:abcnre.training.components.metrics:   Learning rate: 0.0001
# INFO:abcnre.training.components.metrics:   LR scheduler: reduce_on_plateau
# INFO:abcnre.training.components.metrics:   Batch size: 512
# INFO:abcnre.training.components.metrics:   Samples/epoch: 20480
# INFO:abcnre.training.components.metrics:   Max epochs: 200
# INFO:abcnre.training.components.metrics:   Stopping rules: Enabled
# INFO:abcnre.training.components.setup:Setting up regressor training
# INFO:abcnre.training.components.setup:Epochs: 200, Batch size: 512, Batches/epoch: 40
# SHapes: input: (1000, 100, 1), output: (1000, 1), n_simulations: 1000
# INFO:abcnre.training.registry:Registered networks: MLP, DeepSet, ConditionedDeepSet
# INFO:abcnre.training.registry:Created DeepSet network (from 'DeepSet') for regressor
# INFO:abcnre.training.registry:Network args: {'activation': 'relu', 'use_layer_norm': True, 'dropout_rate': 0.0, 'pooling_type': 'mean', 'phi_hidden_dims': [64, 64, 32], 'rho_hidden_dims': [64, 64, 32], 'output_dim': 4}
# INFO:abcnre.training.components.setup:Created network: DeepSet
# INFO:abcnre.training.components.setup:Network initialized with 15,492 parameters
# INFO:abcnre.training.components.setup:Using same generator for validation data
# INFO:abcnre.training.components.setup:Creating pre-simulated validation set: 10000 samples
# INFO:abcnre.training.optimization:Using AdamW with native weight_decay=0.001 support.
# INFO:abcnre.training.components.setup:Setup complete. Initial simulations: 10010
# INFO:abcnre.training.components.schedulers:Initialized reduce-on-plateau scheduler
# INFO:abcnre.training.components.metrics:============================================================
# INFO:abcnre.training.components.metrics:Starting regressor training
# INFO:abcnre.training.components.metrics:Epochs: 200, Batch size: 512, Batches/epoch: 40
# INFO:abcnre.training.components.metrics:============================================================
# INFO:abcnre.training.train:Active stopping criteria: ['max_epochs', 'early_stopping', 'lr_stopping', 'sample_stopping']
# INFO:abcnre.training.components.metrics:Epoch   1/200 | Loss: train = 5.331292 val = 4.108831 | LR: 1.00e-04 | Samples: 30,490 | Time: 14.9s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=4.46s Train=9.11s Overhead=0.04s (Sim/Train: 0.5x)
# INFO:abcnre.training.components.metrics:Epoch  11/200 | Loss: train = 2.299252 val = 2.239544 | LR: 1.00e-04 | Samples: 235,290 | Time: 55.5s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.64s Train=2.89s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 83.4% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 11.9 minutes
# INFO:abcnre.training.components.metrics:Epoch  21/200 | Loss: train = 1.818179 val = 1.776182 | LR: 1.00e-04 | Samples: 440,090 | Time: 90.2s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.46s Train=2.52s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 84.3% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 9.6 minutes
# INFO:abcnre.training.components.metrics:Epoch  31/200 | Loss: train = 1.166587 val = 1.093851 | LR: 1.00e-04 | Samples: 644,890 | Time: 123.5s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.51s Train=2.50s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 83.2% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 8.8 minutes
# INFO:abcnre.training.components.metrics:Epoch  41/200 | Loss: train = 0.774489 val = 0.739231 | LR: 1.00e-04 | Samples: 849,690 | Time: 158.6s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.45s Train=2.51s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 84.4% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 8.7 minutes
# INFO:abcnre.training.components.metrics:Epoch  51/200 | Loss: train = 0.637804 val = 0.605884 | LR: 1.00e-04 | Samples: 1,054,490 | Time: 192.8s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.48s Train=2.61s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 84.2% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 7.9 minutes
# INFO:abcnre.training.components.metrics:Epoch  61/200 | Loss: train = 0.561606 val = 0.563262 | LR: 1.00e-04 | Samples: 1,259,290 | Time: 227.7s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.45s Train=2.50s Overhead=0.01s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 84.5% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 7.6 minutes
# INFO:abcnre.training.components.metrics:Epoch  71/200 | Loss: train = 0.552786 val = 0.545405 | LR: 1.00e-04 | Samples: 1,464,090 | Time: 266.4s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.76s Train=4.27s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 85.2% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 7.7 minutes
# INFO:abcnre.training.components.metrics:Epoch  81/200 | Loss: train = 0.539409 val = 0.514342 | LR: 1.00e-04 | Samples: 1,668,890 | Time: 310.0s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.47s Train=2.75s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 84.7% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 8.0 minutes
# INFO:abcnre.training.components.metrics:Epoch  91/200 | Loss: train = 0.509503 val = 0.541149 | LR: 1.00e-04 | Samples: 1,873,690 | Time: 348.5s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.50s Train=2.71s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 84.4% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 6.5 minutes
# INFO:abcnre.training.components.metrics:Epoch 101/200 | Loss: train = 0.497028 val = 0.495216 | LR: 1.00e-04 | Samples: 2,078,490 | Time: 386.7s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.48s Train=2.67s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 84.9% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 5.8 minutes
# INFO:abcnre.training.components.metrics:Epoch 111/200 | Loss: train = 0.492095 val = 0.494258 | LR: 1.00e-04 | Samples: 2,283,290 | Time: 423.1s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.46s Train=2.71s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 84.7% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 5.0 minutes
# INFO:abcnre.training.components.metrics:Epoch 121/200 | Loss: train = 0.486732 val = 0.496811 | LR: 1.00e-04 | Samples: 2,488,090 | Time: 466.3s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.69s Train=3.14s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 82.6% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 5.3 minutes
# INFO:abcnre.training.components.metrics:Epoch 131/200 | Loss: train = 0.490129 val = 0.492870 | LR: 1.00e-04 | Samples: 2,692,890 | Time: 510.2s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=1.00s Train=4.23s Overhead=0.03s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 82.8% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 4.7 minutes
# INFO:abcnre.training.components.schedulers:Learning rate reduced: 1.00e-04 -> 5.00e-05
# INFO:abcnre.training.components.metrics:Learning rate reduced: 1.00e-04 -> 5.00e-05 (0.50x)
# INFO:abcnre.training.optimization:Using AdamW with native weight_decay=0.001 support.
# INFO:abcnre.training.components.metrics:Epoch 141/200 | Loss: train = 0.464873 val = 0.469806 | LR: 5.00e-05 | Samples: 2,897,690 | Time: 556.8s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.61s Train=3.05s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 83.5% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 4.2 minutes
# INFO:abcnre.training.components.metrics:Epoch 151/200 | Loss: train = 0.468228 val = 0.462237 | LR: 5.00e-05 | Samples: 3,102,490 | Time: 600.5s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.76s Train=3.14s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 81.9% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 3.3 minutes
# INFO:abcnre.training.components.schedulers:Learning rate reduced: 5.00e-05 -> 2.50e-05
# INFO:abcnre.training.components.metrics:Learning rate reduced: 5.00e-05 -> 2.50e-05 (0.50x)
# INFO:abcnre.training.optimization:Using AdamW with native weight_decay=0.001 support.
# INFO:abcnre.training.components.metrics:Epoch 161/200 | Loss: train = 0.470266 val = 0.466259 | LR: 2.50e-05 | Samples: 3,307,290 | Time: 649.0s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.60s Train=3.45s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 85.3% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 2.9 minutes
# INFO:abcnre.training.components.metrics:Epoch 171/200 | Loss: train = 0.461313 val = 0.459205 | LR: 2.50e-05 | Samples: 3,512,090 | Time: 692.2s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.68s Train=3.53s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 84.1% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 2.0 minutes
# INFO:abcnre.training.components.metrics:Epoch 181/200 | Loss: train = 0.463109 val = 0.467022 | LR: 2.50e-05 | Samples: 3,716,890 | Time: 752.3s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.96s Train=4.40s Overhead=0.03s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 80.2% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 1.7 minutes
# INFO:abcnre.training.components.metrics:Epoch 191/200 | Loss: train = 0.458650 val = 0.455536 | LR: 2.50e-05 | Samples: 3,921,690 | Time: 805.9s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=1.04s Train=4.01s Overhead=0.04s (Sim/Train: 0.3x)
# INFO:abcnre.training.train:Training efficiency: 81.3% (higher = less time on data generation)
# INFO:abcnre.training.components.schedulers:Learning rate reduced: 2.50e-05 -> 1.25e-05
# INFO:abcnre.training.components.metrics:Learning rate reduced: 2.50e-05 -> 1.25e-05 (0.50x)
# INFO:abcnre.training.optimization:Using AdamW with native weight_decay=0.001 support.
# INFO:abcnre.training.components.metrics:============================================================
# INFO:abcnre.training.components.metrics:Training completed!
# INFO:abcnre.training.components.metrics:Total time: 866.9s (14.4m)
# INFO:abcnre.training.components.metrics:Epochs completed: 200
# INFO:abcnre.training.components.metrics:Final train loss: 0.475342
# INFO:abcnre.training.components.metrics:Final val loss: 0.460088
# INFO:abcnre.training.components.metrics:Total simulations: 4,106,010
# INFO:abcnre.training.components.metrics:Best val loss: 0.453284 (epoch 198)
# INFO:abcnre.training.components.metrics:============================================================
# INFO:abcnre.training.train:Final stopping rules status: {'enabled': True, 'max_epochs': 500, 'active_criteria': ['max_epochs', 'early_stopping', 'lr_stopping', 'sample_stopping'], 'config': {'max_epochs': 500, 'early_stopping': {'enabled': True, 'monitor': 'validation_loss', 'patience': 15, 'min_delta': 0.0001, 'restore_best_weights': True, 'mode': 'min'}, 'lr_stopping': {'enabled': True, 'min_lr': 1e-07}, 'convergence_stopping': {'enabled': False, 'tolerance': 1e-06, 'patience': 5}, 'plateau_stopping': {'enabled': False, 'patience': 20, 'threshold': 1e-05}, 'time_stopping': {'enabled': False, 'max_time_hours': None}, 'sample_stopping': {'enabled': True, 'max_samples': inf}, 'simulation_stopping': {'enabled': False, 'max_simulations': None}}}
# INFO:abcnre.training.train:============================================================
# INFO:abcnre.training.train:DETAILED TIMING BREAKDOWN
# INFO:abcnre.training.train:============================================================
# INFO:abcnre.training.train:Total training time: 866.93s (14.4m)
# INFO:abcnre.training.train:  - Pure simulation time: 135.85s (15.7%)
# INFO:abcnre.training.train:  - Pure training time: 664.58s (76.7%)
# INFO:abcnre.training.train:  - Overhead time: 4.29s (0.5%)
# INFO:abcnre.training.train:Average sim/train ratio: 0.20x
# INFO:abcnre.training.train:Note: Using on-the-fly simulation - simulation time includes full model execution
# INFO:abcnre.training.train:============================================================
# INFO:abcnre.training.components.metrics:Training Metrics Summary:
# INFO:abcnre.training.components.metrics:   train_loss: min=0.449043, max=5.331292, mean=0.790651
# INFO:abcnre.training.components.metrics:   val_loss: min=0.453284, max=4.108831, mean=0.769540
# INFO:abcnre.simulation.simulator:Updating model's summary statistics function...
# INFO:abcnre.simulation.simulator:Created temporary observed data for prior sampling mode
# INFO:abcnre.simulation.simulator:Summary statistics learned and updated successfully!
#     - Original data dimension: (100, 1)
#     - Learned summary statistics dimension: None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 23
#      20 simulator.train_summary_network(subkey_learn, regressor_config)
#      22 key, subkey_check = jax.random.split(key)
# ---> 23 simulator.check_summary_stats_correlation(
#      24     subkey_check,
#      25     n_samples=10000)
#
# File ~/Documents/Recherche/ABC-SBI-1/abcnre/src/abcnre/simulation/simulator.py:572, in ABCSimulator.check_summary_stats_correlation(self, key, n_samples)
#     568 summary_stats = self.summary_stat_fn(x_samples)
#     571 # Compute correlation
# --> 572 correlation_matrix = jnp.corrcoef(
#     573     summary_stats.flatten(), phi_samples.flatten()
#     574 )
#     575 phi_summary_correlation = correlation_matrix[0, 1]
#     577 if self.config["verbose"]:
#
#     [... skipping hidden 11 frame]
#
# File ~/.pyenv/versions/jax_env/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:8682, in corrcoef(x, y, rowvar)
#    8678 @util.implements(np.corrcoef)
#    8679 @partial(jit, static_argnames=('rowvar',))
#    8680 def corrcoef(x: ArrayLike, y: ArrayLike | None = None, rowvar: bool = True) -> Array:
#    8681   util.check_arraylike("corrcoef", x)
# -> 8682   c = cov(x, y, rowvar)
#    8683   if len(shape(c)) == 0:
#    8684     # scalar - this should yield nan for values (nan/nan, inf/inf, 0/0), 1 otherwise
#    8685     return ufuncs.divide(c, c)
#
#     [... skipping hidden 11 frame]
#
# File ~/.pyenv/versions/jax_env/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:8636, in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    8634   if not rowvar and y_arr.shape[0] != 1:
#    8635     y_arr = y_arr.T
# -> 8636   X = concatenate((X, y_arr), axis=0)
#    8637 if ddof is None:
#    8638   ddof = 1 if bias == 0 else 0
#
# File ~/.pyenv/versions/jax_env/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:3151, in concatenate(arrays, axis, dtype)
#    3149 k = 16
#    3150 while len(arrays_out) > 1:
# -> 3151   arrays_out = [lax.concatenate(arrays_out[i:i+k], axis)
#    3152                 for i in range(0, len(arrays_out), k)]
#    3153 return arrays_out[0]
#
# File ~/.pyenv/versions/jax_env/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:3151, in <listcomp>(.0)
#    3149 k = 16
#    3150 while len(arrays_out) > 1:
# -> 3151   arrays_out = [lax.concatenate(arrays_out[i:i+k], axis)
#    3152                 for i in range(0, len(arrays_out), k)]
#    3153 return arrays_out[0]
#
#     [... skipping hidden 7 frame]
#
# File ~/.pyenv/versions/jax_env/lib/python3.10/site-packages/jax/_src/lax/lax.py:3474, in _concatenate_shape_rule(*operands, **kwargs)
#    3470   msg = ("Cannot concatenate arrays with shapes that differ in dimensions "
#    3471          "other than the one being concatenated: concatenating along "
#    3472          "dimension {} for shapes {}.")
#    3473   shapes = [operand.shape for operand in operands]
# -> 3474   raise TypeError(msg.format(dimension, ", ".join(map(str, shapes))))
#    3476 concat_size = sum(o.shape[dimension] for o in operands)
#    3477 ex_shape = operands[0].shape
#
# TypeError: Cannot concatenate arrays with shapes that differ in dimensions other than the one being concatenated: concatenating along dimension 0 for shapes (1, 40000), (1, 10000).

# %%
n_samples = 1000 
key, subkey = jax.random.split(key)
phi_samples, x_samples = simulator.model.sample_phi_x_multiple(
    subkey, n_samples=n_samples
)
# Compute summary statistics for the generated samples
summary_stats = simulator.summary_stat_fn(x_samples)

# %%
print(f'Shapes: phi_samples: {phi_samples.shape}, x_samples: {x_samples.shape}, summary_stats: {summary_stats.shape}')
# Out:
# Shapes: phi_samples: (1000, 1), x_samples: (1000, 100, 1), summary_stats: (1000, 4)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import jax.numpy as jnp
for i in range(phi_samples.shape[1]):
    plt.scatter(phi_samples[:,i], summary_stats[:, i])
    plt.title(f'Correlation between phi_samples[:, {i}] and summary_stats[:, {i}] = {jnp.corrcoef(phi_samples[:,i], summary_stats[:, i])[0, 1]:.2%}')
    plt.show()

# %%
print("--- Step 2.1: Sample x_obs and initialize the ABCSimulator ---")
import jax.numpy as jnp
model = simulator.model

key, key_prior = jax.random.split(key)
true_theta = model.get_prior_sample(key_prior)

true_theta = jnp.array([3., 1., 2., .5])
true_phi = model.transform_phi(true_theta)

key, subkey_sample = jax.random.split(key)
x_obs = model.simulate_data(subkey_sample, true_theta)

simulator.update_observed_data(x_obs)
print(f"Observation x_obs shape: {x_obs.shape}")
# Out:
# --- Step 2.1: Sample x_obs and initialize the ABCSimulator ---
# Observation x_obs shape: (100, 1)

# %%
quantiles = jnp.array([1., .5, .1, .01])
import matplotlib.pyplot as plt
import seaborn as sns

f,ax = plt.subplots(1, 4, figsize=(20,5))

for quantile_epsilon in quantiles:

    
    key, subkey_epsilon = jax.random.split(key)
    simulator.set_epsilon_from_quantile(key = subkey_epsilon, quantile_distance=quantile_epsilon, n_samples=10000)
    
    n_samples = 1000
    key, subkey_sample = jax.random.split(key)
    results = simulator.sampler.sample(key=subkey_sample, n_samples=n_samples)
    
    thetas, xs = results.theta, results.data

    sns.kdeplot(thetas[:, 0], ax=ax[0], label=f"Quantile {quantile_epsilon}")
    sns.kdeplot(thetas[:, 1], ax=ax[1], label=f"Quantile {quantile_epsilon}")
    sns.kdeplot(thetas[:, 2], ax=ax[2], label=f"Quantile {quantile_epsilon}")
    sns.kdeplot(thetas[:, 3], ax=ax[3], label=f"Quantile {quantile_epsilon}")


ax[0].set_title("A")
ax[1].set_title("B")
ax[2].set_title("g")
ax[3].set_title("k")
ax[0].axvline(true_theta[0], color='red', linestyle='--', label='True A')
ax[1].axvline(true_theta[1], color='red', linestyle='--', label='True B')
ax[2].axvline(true_theta[2], color='red', linestyle='--', label='True g')
ax[3].axvline(true_theta[3], color='red', linestyle='--', label='True k')
plt.legend()
plt.show()
# Out:
# DEBUG: Discrepancy function called with data1 = (4,) data2 = (4,)
# INFO:abcnre.simulation.simulator:Computed epsilon = 2.616537 for 50.0% quantile
# INFO:abcnre.simulation.simulator:Computed epsilon = 0.578643 for 10.0% quantile
# INFO:abcnre.simulation.simulator:Computed epsilon = 0.103865 for 1.0% quantile

# %%
alpha = 1.
quantile_distance = alpha 
key, subkey_epsilon = jax.random.split(key)
simulator.set_epsilon_from_quantile(key = subkey_epsilon, quantile_distance=quantile_distance, n_samples=10000)

# %%
print("--- Step 2.2: Save model to YAML (Optional) ---")

from abcnre.simulation import save_simulator_to_yaml


save_simulator_to_yaml(
    simulator,
    results_dir / "simulator" / "simulator_{}.yaml".format(model_config["model_args"]["parameter_of_interest"]),
    overwrite=True
)
# Out:
# INFO:abcnre.simulation.models.io:Model saved to: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/simulator/simulator_B_model.yml
# INFO:abcnre.simulation.io:Saved model configuration to: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/simulator/simulator_B_model.yml
# INFO:abcnre.simulation.io:Saved observed data to: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/simulator/simulator_B_observed_data.npy
# INFO:abcnre.training.config:Configuration saved to /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/simulator/simulator_B_summary_network_config.yml
# INFO:abcnre.simulation.io:Saved summary network weights to: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/simulator/simulator_B_summary_network_weights.npz
# INFO:abcnre.simulation.io:ABCSimulator configuration saved to: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/simulator/simulator_B.yaml
# --- Step 2.2: Save model to YAML (Optional) ---

# %%
print("--- Step 2.3 : Load model from YAML and check (Optional) ---")

from abcnre.simulation import load_simulator_from_yaml
simulator_loaded = load_simulator_from_yaml(
    results_dir / "simulator" / "simulator_{}.yaml".format(model_config["model_args"]["parameter_of_interest"]),
)

from abcnre.utils.comparison import are_simulators_equivalent

simulators_match = are_simulators_equivalent(simulator, simulator_loaded)
print(f"Simulators match: {'YES' if simulators_match else 'NO'}")
# Out:
# INFO:abcnre.simulation.io:Loaded model: GAndKModel
# INFO:abcnre.simulation.io:Loaded observed data from: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/simulator/simulator_B_observed_data.npy
# INFO:abcnre.simulation.simulator:Using provided epsilon = inf
# INFO:abcnre.training.config:Loaded configuration from /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/simulator/simulator_B_summary_network_config.yml
# INFO:abcnre.simulation.io:Loaded summary network config from: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/simulator/simulator_B_summary_network_config.yml
# INFO:abcnre.simulation.io:Loaded summary network weights from: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/simulator/simulator_B_summary_network_weights.npz
# INFO:abcnre.training.registry:Registered networks: MLP, DeepSet, ConditionedDeepSet
# INFO:abcnre.training.registry:Created DeepSet network (from 'DeepSet') for regressor
# INFO:abcnre.training.registry:Network args: {'activation': 'relu', 'use_layer_norm': True, 'dropout_rate': 0.0, 'pooling_type': 'mean', 'phi_hidden_dims': [64, 64, 32], 'rho_hidden_dims': [64, 64, 32], 'output_dim': 4}
# INFO:abcnre.simulation.io:Summary network loaded and integrated into simulator
# --- Step 2.3 : Load model from YAML and check (Optional) ---
# DEBUG: Summary statistics for data = (100, 1)
# Simulators match: YES

# %%
from abcnre.training import NNConfig, NetworkConfig, TrainingConfig, get_nn_config
print("--- Step 3.1: Create NNConfig for training ---")
nn_config = get_nn_config(network_name="conditioned_deepset",
                          network_size = "large",
                          training_size = "extended",
                          task_type = "classifier",
                          lr_scheduler_name = "reduce_on_plateau",
                          lr_scheduler_variant = "default",
                          stopping_rules_variant = "balanced",
                          experiment_name = None)
# Out:
# INFO:abcnre.training.config:Using custom lr_scheduler: reduce_on_plateau_default
# INFO:abcnre.training.config:Using stopping rules: balanced
# INFO:abcnre.training.config:Created NN config: classifier_conditioned_deepset_large_extended (task: classifier)
# --- Step 3.1: Create NNConfig for training ---

# %%
print("--- Step 3.2: Create NeuralRatioEstimator ---")

from abcnre.inference import NeuralRatioEstimator    

estimator = NeuralRatioEstimator(
    nn_config=nn_config,
    simulator=simulator)
# Out:
# --- Step 3.2: Create NeuralRatioEstimator ---

# %%
print("--- Step 3.3: Train the NeuralRatioEstimator ---")


key, key_train = jax.random.split(key)
res = estimator.train(key_train, n_phi_to_store = 10000)  # Store few phi samples
# Out:
# --- Step 3.3: Train the NeuralRatioEstimator ---
# INFO:abcnre.inference.estimator:Using ConditionedDeepSet without summary statistics
# INFO:abcnre.inference.estimator:Storing 10000 phi during training
# INFO:abcnre.training.components.metrics:Configuration Summary:
# INFO:abcnre.training.components.metrics:   Task: classifier
# INFO:abcnre.training.components.metrics:   Network: ConditionedDeepSet
# INFO:abcnre.training.components.metrics:   Optimizer: adamw
# INFO:abcnre.training.components.metrics:   Learning rate: 0.0001
# INFO:abcnre.training.components.metrics:   LR scheduler: reduce_on_plateau
# INFO:abcnre.training.components.metrics:   Batch size: 512
# INFO:abcnre.training.components.metrics:   Samples/epoch: 20480
# INFO:abcnre.training.components.metrics:   Max epochs: 200
# INFO:abcnre.training.components.metrics:   Stopping rules: Enabled
# INFO:abcnre.training.components.metrics:   Phi storage: 10000 values
# INFO:abcnre.training.components.setup:Setting up classifier training
# INFO:abcnre.training.components.setup:Epochs: 200, Batch size: 512, Batches/epoch: 40
# dict_keys(['x', 'theta'])
# DEBUG io samples : input  x=(10000, 100, 1) input theta=(10000, 1), output=(10000,), n_simulations=5000
# INFO:abcnre.training.registry:Registered networks: MLP, DeepSet, ConditionedDeepSet
# INFO:abcnre.training.registry:Created ConditionedDeepSet network (from 'ConditionedDeepSet') for classifier
# INFO:abcnre.training.registry:Network args: {'activation': 'relu', 'use_layer_norm': True, 'dropout_rate': 0.0, 'pooling_type': 'mean', 'conditioning_mode': 'concat', 'phi_hidden_dims': [64, 64, 32], 'rho_hidden_dims': [64, 64, 32], 'output_dim': 1}
# INFO:abcnre.training.components.setup:Created network: ConditionedDeepSet
# INFO:abcnre.training.components.setup:Network initialized with 15,521 parameters
# INFO:abcnre.training.components.setup:Using same generator for validation data
# INFO:abcnre.training.components.setup:Creating pre-simulated validation set: 10000 samples
# INFO:abcnre.training.optimization:Using AdamW with native weight_decay=0.001 support.
# INFO:abcnre.training.components.setup:Setup complete. Initial simulations: 5005
# INFO:abcnre.training.components.schedulers:Initialized reduce-on-plateau scheduler
# INFO:abcnre.training.components.loop:Initialized phi storage for 10000 values
# INFO:abcnre.training.components.metrics:============================================================
# INFO:abcnre.training.components.metrics:Starting classifier training
# INFO:abcnre.training.components.metrics:Epochs: 200, Batch size: 512, Batches/epoch: 40
# INFO:abcnre.training.components.metrics:============================================================
# INFO:abcnre.training.train:Active stopping criteria: ['max_epochs', 'early_stopping', 'lr_stopping']
# INFO:abcnre.training.components.metrics:Epoch   1/200 | Loss: train = 0.721076 val = 0.682109 | Acc: train = 55.86% val = 54.74% | LR: 1.00e-04 | Samples: 30,490 | Sims: 15,245 | Time: 6.5s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=1.57s Train=3.28s Overhead=0.03s (Sim/Train: 0.5x)
# INFO:abcnre.training.components.metrics:Epoch  11/200 | Loss: train = 0.590312 val = 0.586631 | Acc: train = 69.14% val = 67.00% | LR: 1.00e-04 | Samples: 235,290 | Sims: 117,645 | Time: 81.7s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=1.38s Train=5.12s Overhead=0.02s (Sim/Train: 0.3x)
# INFO:abcnre.training.train:Training efficiency: 81.5% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 20.4 minutes
# INFO:abcnre.training.components.metrics:Epoch  21/200 | Loss: train = 0.551591 val = 0.546918 | Acc: train = 69.73% val = 70.38% | LR: 1.00e-04 | Samples: 440,090 | Sims: 220,045 | Time: 151.4s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=1.18s Train=5.28s Overhead=0.04s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 80.8% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 18.2 minutes
# INFO:abcnre.training.components.metrics:Epoch  31/200 | Loss: train = 0.531825 val = 0.530214 | Acc: train = 67.38% val = 71.50% | LR: 1.00e-04 | Samples: 644,890 | Sims: 322,445 | Time: 220.5s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=1.19s Train=4.75s Overhead=0.04s (Sim/Train: 0.3x)
# INFO:abcnre.training.train:Training efficiency: 81.3% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 16.3 minutes
# INFO:abcnre.training.components.metrics:Epoch  41/200 | Loss: train = 0.526133 val = 0.518943 | Acc: train = 72.07% val = 73.06% | LR: 1.00e-04 | Samples: 849,690 | Sims: 424,845 | Time: 291.0s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.92s Train=4.04s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 80.9% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 16.2 minutes
# INFO:abcnre.training.components.metrics:Epoch  51/200 | Loss: train = 0.514664 val = 0.509838 | Acc: train = 72.66% val = 73.15% | LR: 1.00e-04 | Samples: 1,054,490 | Sims: 527,245 | Time: 351.7s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.88s Train=3.79s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 82.0% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 13.0 minutes
# INFO:abcnre.training.components.metrics:Epoch  61/200 | Loss: train = 0.511990 val = 0.505870 | Acc: train = 72.66% val = 73.83% | LR: 1.00e-04 | Samples: 1,259,290 | Sims: 629,645 | Time: 410.4s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=1.28s Train=4.95s Overhead=0.02s (Sim/Train: 0.3x)
# INFO:abcnre.training.train:Training efficiency: 81.9% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 12.0 minutes
# INFO:abcnre.training.components.metrics:Epoch  71/200 | Loss: train = 0.505581 val = 0.500288 | Acc: train = 72.46% val = 73.88% | LR: 1.00e-04 | Samples: 1,464,090 | Sims: 732,045 | Time: 478.2s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=1.04s Train=4.99s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 82.3% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 12.9 minutes
# INFO:abcnre.training.components.metrics:Epoch  81/200 | Loss: train = 0.505749 val = 0.497928 | Acc: train = 75.20% val = 74.11% | LR: 1.00e-04 | Samples: 1,668,890 | Sims: 834,445 | Time: 542.9s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.86s Train=4.37s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 82.1% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 11.4 minutes
# INFO:abcnre.training.components.metrics:Epoch  91/200 | Loss: train = 0.498863 val = 0.495366 | Acc: train = 75.59% val = 74.50% | LR: 1.00e-04 | Samples: 1,873,690 | Sims: 936,845 | Time: 609.3s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.95s Train=3.89s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 81.2% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 10.2 minutes
# INFO:abcnre.training.components.schedulers:Learning rate reduced: 1.00e-04 -> 5.00e-05
# INFO:abcnre.training.components.metrics:Learning rate reduced: 1.00e-04 -> 5.00e-05 (0.50x)
# INFO:abcnre.training.optimization:Using AdamW with native weight_decay=0.001 support.
# INFO:abcnre.training.components.metrics:Epoch 101/200 | Loss: train = 0.495842 val = 0.492169 | Acc: train = 72.46% val = 74.84% | LR: 5.00e-05 | Samples: 2,078,490 | Sims: 1,039,245 | Time: 678.6s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=1.19s Train=4.88s Overhead=0.03s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 83.0% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 10.0 minutes
# INFO:abcnre.training.components.schedulers:Learning rate reduced: 5.00e-05 -> 2.50e-05
# INFO:abcnre.training.components.metrics:Learning rate reduced: 5.00e-05 -> 2.50e-05 (0.50x)
# INFO:abcnre.training.optimization:Using AdamW with native weight_decay=0.001 support.
# INFO:abcnre.training.components.metrics:Epoch 111/200 | Loss: train = 0.490868 val = 0.489060 | Acc: train = 74.41% val = 74.93% | LR: 2.50e-05 | Samples: 2,283,290 | Sims: 1,141,645 | Time: 750.1s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.84s Train=4.06s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 83.6% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 9.4 minutes
# INFO:abcnre.training.components.metrics:Epoch 121/200 | Loss: train = 0.498308 val = 0.488971 | Acc: train = 73.63% val = 75.13% | LR: 2.50e-05 | Samples: 2,488,090 | Sims: 1,244,045 | Time: 814.9s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.83s Train=3.73s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 81.0% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 7.6 minutes
# INFO:abcnre.training.components.schedulers:Learning rate reduced: 2.50e-05 -> 1.25e-05
# INFO:abcnre.training.components.metrics:Learning rate reduced: 2.50e-05 -> 1.25e-05 (0.50x)
# INFO:abcnre.training.optimization:Using AdamW with native weight_decay=0.001 support.
# INFO:abcnre.training.components.metrics:Epoch 131/200 | Loss: train = 0.489906 val = 0.488821 | Acc: train = 77.34% val = 74.81% | LR: 1.25e-05 | Samples: 2,692,890 | Sims: 1,346,445 | Time: 878.0s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.67s Train=3.34s Overhead=0.01s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 80.0% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 6.3 minutes
# INFO:abcnre.training.components.schedulers:Learning rate reduced: 1.25e-05 -> 6.25e-06
# INFO:abcnre.training.components.metrics:Learning rate reduced: 1.25e-05 -> 6.25e-06 (0.50x)
# INFO:abcnre.training.optimization:Using AdamW with native weight_decay=0.001 support.
# INFO:abcnre.training.components.metrics:Epoch 141/200 | Loss: train = 0.490208 val = 0.486938 | Acc: train = 75.98% val = 75.14% | LR: 6.25e-06 | Samples: 2,897,690 | Sims: 1,448,845 | Time: 940.9s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.66s Train=3.43s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 81.9% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 5.5 minutes
# INFO:abcnre.training.components.schedulers:Learning rate reduced: 6.25e-06 -> 3.13e-06
# INFO:abcnre.training.components.metrics:Learning rate reduced: 6.25e-06 -> 3.13e-06 (0.50x)
# INFO:abcnre.training.optimization:Using AdamW with native weight_decay=0.001 support.
# INFO:abcnre.training.components.metrics:Epoch 151/200 | Loss: train = 0.490277 val = 0.486971 | Acc: train = 77.15% val = 75.19% | LR: 3.13e-06 | Samples: 3,102,490 | Sims: 1,551,245 | Time: 1000.8s
# INFO:abcnre.training.train:Timing [On-the-fly]: Sim=0.90s Train=3.95s Overhead=0.02s (Sim/Train: 0.2x)
# INFO:abcnre.training.train:Training efficiency: 81.4% (higher = less time on data generation)
# INFO:abcnre.training.train:ETA: 4.3 minutes
# INFO:abcnre.training.components.metrics:Early stopping at epoch 156: Early stopping at epoch 156: No improvement in validation loss for 15 epochs (best: 0.486938, current: 0.486946)
# INFO:abcnre.training.components.metrics:============================================================
# INFO:abcnre.training.components.metrics:Training completed!
# INFO:abcnre.training.components.metrics:Total time: 1028.1s (17.1m)
# INFO:abcnre.training.components.metrics:Epochs completed: 156
# INFO:abcnre.training.components.metrics:Final train loss: 0.494261
# INFO:abcnre.training.components.metrics:Final val loss: 0.486946
# INFO:abcnre.training.components.metrics:Final val accuracy: 75.1%
# INFO:abcnre.training.components.metrics:Total simulations: 1,602,445
# INFO:abcnre.training.components.metrics:Best val loss: 0.486868 (epoch 147)
# INFO:abcnre.training.components.metrics:============================================================
# INFO:abcnre.training.components.loop:Phi storage completed: 10000 values stored (target: 10000)
# INFO:abcnre.training.train:Final stopping rules status: {'enabled': True, 'max_epochs': 500, 'active_criteria': ['max_epochs', 'early_stopping', 'lr_stopping'], 'config': {'max_epochs': 500, 'early_stopping': {'enabled': True, 'monitor': 'validation_loss', 'patience': 15, 'min_delta': 0.0001, 'restore_best_weights': True, 'mode': 'min'}, 'lr_stopping': {'enabled': True, 'min_lr': 1e-07}, 'convergence_stopping': {'enabled': False, 'tolerance': 1e-06, 'patience': 5}, 'plateau_stopping': {'enabled': False, 'patience': 20, 'threshold': 1e-05}, 'time_stopping': {'enabled': False, 'max_time_hours': None}, 'sample_stopping': {'enabled': False, 'max_samples': None}, 'simulation_stopping': {'enabled': False, 'max_simulations': None}}}
# INFO:abcnre.training.train:============================================================
# INFO:abcnre.training.train:DETAILED TIMING BREAKDOWN
# INFO:abcnre.training.train:============================================================
# INFO:abcnre.training.train:Total training time: 1028.14s (17.1m)
# INFO:abcnre.training.train:  - Pure simulation time: 162.30s (15.8%)
# INFO:abcnre.training.train:  - Pure training time: 730.32s (71.0%)
# INFO:abcnre.training.train:  - Overhead time: 4.07s (0.4%)
# INFO:abcnre.training.train:Average sim/train ratio: 0.22x
# INFO:abcnre.training.train:Note: Using on-the-fly simulation - simulation time includes full model execution
# INFO:abcnre.training.train:============================================================
# INFO:abcnre.training.components.metrics:Training Metrics Summary:
# INFO:abcnre.training.components.metrics:   train_loss: min=0.486741, max=0.721076, mean=0.517597
# INFO:abcnre.training.components.metrics:   val_loss: min=0.486868, max=0.682109, mean=0.513219
# INFO:abcnre.training.components.metrics:   train_accuracy: min=0.559, max=0.779, mean=0.728
# INFO:abcnre.training.components.metrics:   val_accuracy: min=0.547, max=0.752, mean=0.730
# INFO:abcnre.training.train:Stored phi values: 10000
# Neural Ratio Estimator training completed successfully!
#    - Final train loss: 0.4942610263824463
#    - Total simulations: 1602445

# %%
print("--- Step 3.4: Save the NeuralRatioEstimator to YAML (Optional) ---")

from abcnre.inference.io import save_estimator_to_yaml
save_estimator_to_yaml(
    estimator,
    results_dir / "estimator" / f"estimator_{model_config['model_args']['parameter_of_interest']}_quantile_{quantile_distance}.yaml",
    overwrite=True
)
# Out:
# INFO:abcnre.training.config:Configuration saved to /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_B_quantile_1.0_classif_config.yaml
# INFO:abcnre.inference.io:Saved classifier config to: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_B_quantile_1.0_classif_config.yaml
# INFO:abcnre.simulation.models.io:Model saved to: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_B_quantile_1.0_simulator_model.yml
# INFO:abcnre.simulation.io:Saved model configuration to: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_B_quantile_1.0_simulator_model.yml
# INFO:abcnre.simulation.io:Saved observed data to: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_B_quantile_1.0_simulator_observed_data.npy
# INFO:abcnre.training.config:Configuration saved to /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_B_quantile_1.0_simulator_summary_network_config.yml
# INFO:abcnre.simulation.io:Saved summary network weights to: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_B_quantile_1.0_simulator_summary_network_weights.npz
# INFO:abcnre.simulation.io:ABCSimulator configuration saved to: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_B_quantile_1.0_simulator.yaml
# INFO:abcnre.inference.io:Saved simulator config to: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_B_quantile_1.0_simulator.yaml
# INFO:abcnre.inference.io:Saved classifier params to: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_B_quantile_1.0_classif_params.npz
# INFO:abcnre.inference.io:Saved stored phis to: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_B_quantile_1.0_stored_phis.npy
# INFO:abcnre.inference.io:Saved estimator to: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_B_quantile_1.0.yaml
# --- Step 3.4: Save the NeuralRatioEstimator to YAML (Optional) ---

# %%
print("--- Step 3.5: Load the NeuralRatioEstimator from YAML and check (Optional) ---")

from abcnre.inference import load_estimator_from_yaml

estimator_loaded = load_estimator_from_yaml(
    results_dir / "estimator" / f"estimator_{model_config['model_args']['parameter_of_interest']}_quantile_{quantile_distance}.yaml"
)
from abcnre.utils.comparison import are_estimators_equivalent

estimators_match = are_estimators_equivalent(estimator, estimator_loaded)
print(f"Estimators match: {'YES' if estimators_match else 'NO'}")
# Out:
# INFO:abcnre.training.config:Loaded configuration from /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_all_quantile_1.0_classif_config.yaml
# INFO:abcnre.simulation.io:Loaded model: GAndKModel
# INFO:abcnre.simulation.io:Loaded observed data from: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_all_quantile_1.0_simulator_observed_data.npy
# INFO:abcnre.simulation.simulator:Using provided epsilon = inf
# INFO:abcnre.training.config:Loaded configuration from /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_all_quantile_1.0_simulator_summary_network_config.yml
# INFO:abcnre.simulation.io:Loaded summary network config from: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_all_quantile_1.0_simulator_summary_network_config.yml
# INFO:abcnre.simulation.io:Loaded summary network weights from: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_all_quantile_1.0_simulator_summary_network_weights.npz
# INFO:abcnre.training.registry:Registered networks: MLP, DeepSet, ConditionedDeepSet
# INFO:abcnre.training.registry:Created DeepSet network (from 'DeepSet') for regressor
# INFO:abcnre.training.registry:Network args: {'activation': 'relu', 'use_layer_norm': True, 'dropout_rate': 0.0, 'pooling_type': 'mean', 'phi_hidden_dims': [64, 64, 32], 'rho_hidden_dims': [64, 64, 32], 'output_dim': 4}
# INFO:abcnre.simulation.io:Summary network loaded and integrated into simulator
# INFO:abcnre.training.registry:Registered networks: MLP, DeepSet, ConditionedDeepSet
# INFO:abcnre.training.registry:Created ConditionedDeepSet network (from 'ConditionedDeepSet') for classifier
# INFO:abcnre.training.registry:Network args: {'activation': 'relu', 'use_layer_norm': True, 'dropout_rate': 0.0, 'pooling_type': 'mean', 'conditioning_mode': 'concat', 'phi_hidden_dims': [64, 64, 32], 'rho_hidden_dims': [64, 64, 32], 'output_dim': 1}
# INFO:abcnre.inference.io:Loaded trained params and log ratio function from: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_all_quantile_1.0_classif_params.npz
# INFO:abcnre.inference.io:Loaded stored phis from: /Users/antoineluciano/Documents/Recherche/ABC-SBI-1/abcnre/examples/g_and_K_1D/results/estimator/estimator_all_quantile_1.0_stored_phis.npy
# --- Step 3.5: Load the NeuralRatioEstimator from YAML and check (Optional) ---
# DEBUG: Summary statistics for data = (100, 1)
# Estimators match: YES

# %% [markdown]
# # MCMC

# %%
from abcnre.diagnostics.posterior import get_unnormalized_nre_logpdf, get_unnormalized_corrected_nre_logpdf
from abcnre.diagnostics.viz import plot_mcmc_output
from abcnre.diagnostics.mcmc import run_metropolis, get_tuned_covariance, estimate_effective_sample_size

nre_logpdf = get_unnormalized_nre_logpdf(estimator)

correct_nre_logpdf = get_unnormalized_corrected_nre_logpdf(estimator)

key, subkey_cov = jax.random.split(key)
naive_init = jnp.ones(4) * 0.25
nre_tuning = get_tuned_covariance(key = subkey_cov, logpdf_unnorm = nre_logpdf, initial_state = naive_init, n_tuning_samples=10000)

key, subkey_mcmc = jax.random.split(key)
nre_mcmc = run_metropolis(key = subkey_mcmc, logpdf_unnorm=nre_logpdf, initial_state = naive_init, covariance_matrix = nre_tuning.optimal_covariance, n_samples=50000)


key, subkey_cov = jax.random.split(key)
corrected_nre_tuning = get_tuned_covariance(key = subkey_cov, logpdf_unnorm = correct_nre_logpdf, initial_state = naive_init, n_tuning_samples=10000)


key, subkey_mcmc = jax.random.split(key)
correct_nre_mcmc = run_metropolis(key = subkey_mcmc, logpdf_unnorm=correct_nre_logpdf, initial_state = naive_init, covariance_matrix = corrected_nre_tuning.optimal_covariance, n_samples=50000)


true_logpdf = lambda theta: loglikelihood_gandk_newton(x_obs, theta)

key, subkey_cov = jax.random.split(key)
true_tuning = get_tuned_covariance(key = subkey_cov, logpdf_unnorm = true_logpdf, initial_state = naive_init, n_tuning_samples=10000)

key, subkey_mcmc = jax.random.split(key)
true_mcmc = run_metropolis(key = subkey_mcmc, logpdf_unnorm=true_logpdf, initial_state = naive_init, covariance_matrix = true_tuning.optimal_covariance, n_samples=50000)
# Out:
# INFO:abcnre.diagnostics.mcmc:Robbins-Monro tuning with 10000 samples
# INFO:abcnre.diagnostics.mcmc:Target acceptance rate: 0.234
# INFO:abcnre.diagnostics.mcmc:Target acceptance rate: 0.234
# INFO:abcnre.diagnostics.mcmc:Empirical covariance from 500 preliminary samples
# INFO:abcnre.diagnostics.mcmc:Empirical covariance from 500 preliminary samples
# INFO:abcnre.diagnostics.mcmc:Phase 1/15, scale: 1.0000, acceptance: 0.251, step_size: 1.0000
# INFO:abcnre.diagnostics.mcmc:Phase 1/15, scale: 1.0000, acceptance: 0.251, step_size: 1.0000
# INFO:abcnre.diagnostics.mcmc:Phase 4/15, scale: 0.9008, acceptance: 0.179, step_size: 0.4353
# INFO:abcnre.diagnostics.mcmc:Phase 4/15, scale: 0.9008, acceptance: 0.179, step_size: 0.4353
# INFO:abcnre.diagnostics.mcmc:Phase 7/15, scale: 0.8616, acceptance: 0.251, step_size: 0.3111
# INFO:abcnre.diagnostics.mcmc:Phase 7/15, scale: 0.8616, acceptance: 0.251, step_size: 0.3111
# INFO:abcnre.diagnostics.mcmc:Phase 10/15, scale: 0.8562, acceptance: 0.215, step_size: 0.2512
# INFO:abcnre.diagnostics.mcmc:Phase 10/15, scale: 0.8562, acceptance: 0.215, step_size: 0.2512
# INFO:abcnre.diagnostics.mcmc:Phase 13/15, scale: 0.8455, acceptance: 0.230, step_size: 0.2146
# INFO:abcnre.diagnostics.mcmc:Phase 13/15, scale: 0.8455, acceptance: 0.230, step_size: 0.2146
# INFO:abcnre.diagnostics.mcmc:Robbins-Monro tuning completed. Final scale: 0.8584
# INFO:abcnre.diagnostics.mcmc:Final acceptance rate: 0.279
# INFO:abcnre.diagnostics.mcmc:Robbins-Monro tuning completed. Final scale: 0.8584
# INFO:abcnre.diagnostics.mcmc:Final acceptance rate: 0.279
# INFO:abcnre.diagnostics.mcmc:Running Metropolis-Hastings: 50000 iterations, 50000 final samples, burnin=0, thin=1
# INFO:abcnre.diagnostics.mcmc:Running Metropolis-Hastings: 50000 iterations, 50000 final samples, burnin=0, thin=1
# INFO:abcnre.diagnostics.mcmc:MCMC completed. Final acceptance rate: 0.285
# INFO:abcnre.diagnostics.mcmc:Target acceptance rate: 0.234
# INFO:abcnre.diagnostics.mcmc:Robbins-Monro tuning with 10000 samples
# INFO:abcnre.diagnostics.mcmc:Target acceptance rate: 0.234
# INFO:abcnre.diagnostics.mcmc:MCMC completed. Final acceptance rate: 0.285
# INFO:abcnre.diagnostics.mcmc:Target acceptance rate: 0.234
# INFO:abcnre.diagnostics.mcmc:Robbins-Monro tuning with 10000 samples
# INFO:abcnre.diagnostics.mcmc:Target acceptance rate: 0.234
# INFO:abcnre.diagnostics.mcmc:Empirical covariance from 500 preliminary samples
# INFO:abcnre.diagnostics.mcmc:Empirical covariance from 500 preliminary samples
# INFO:abcnre.diagnostics.mcmc:Phase 1/15, scale: 1.0000, acceptance: 0.149, step_size: 1.0000
# INFO:abcnre.diagnostics.mcmc:Phase 1/15, scale: 1.0000, acceptance: 0.149, step_size: 1.0000
# INFO:abcnre.diagnostics.mcmc:Phase 4/15, scale: 0.7745, acceptance: 0.158, step_size: 0.4353
# INFO:abcnre.diagnostics.mcmc:Phase 4/15, scale: 0.7745, acceptance: 0.158, step_size: 0.4353
# INFO:abcnre.diagnostics.mcmc:Phase 7/15, scale: 0.7016, acceptance: 0.171, step_size: 0.3111
# INFO:abcnre.diagnostics.mcmc:Phase 7/15, scale: 0.7016, acceptance: 0.171, step_size: 0.3111
# INFO:abcnre.diagnostics.mcmc:Phase 10/15, scale: 0.6654, acceptance: 0.182, step_size: 0.2512
# INFO:abcnre.diagnostics.mcmc:Phase 10/15, scale: 0.6654, acceptance: 0.182, step_size: 0.2512
# INFO:abcnre.diagnostics.mcmc:Phase 13/15, scale: 0.6614, acceptance: 0.227, step_size: 0.2146
# INFO:abcnre.diagnostics.mcmc:Phase 13/15, scale: 0.6614, acceptance: 0.227, step_size: 0.2146
# INFO:abcnre.diagnostics.mcmc:Robbins-Monro tuning completed. Final scale: 0.6628
# INFO:abcnre.diagnostics.mcmc:Final acceptance rate: 0.285
# INFO:abcnre.diagnostics.mcmc:Robbins-Monro tuning completed. Final scale: 0.6628
# INFO:abcnre.diagnostics.mcmc:Final acceptance rate: 0.285
# INFO:abcnre.diagnostics.mcmc:Running Metropolis-Hastings: 50000 iterations, 50000 final samples, burnin=0, thin=1
# INFO:abcnre.diagnostics.mcmc:Running Metropolis-Hastings: 50000 iterations, 50000 final samples, burnin=0, thin=1
# INFO:abcnre.diagnostics.mcmc:MCMC completed. Final acceptance rate: 0.250
# INFO:abcnre.diagnostics.mcmc:Target acceptance rate: 0.234
# INFO:abcnre.diagnostics.mcmc:MCMC completed. Final acceptance rate: 0.250
# INFO:abcnre.diagnostics.mcmc:Target acceptance rate: 0.234
# INFO:abcnre.diagnostics.mcmc:Robbins-Monro tuning with 10000 samples
# INFO:abcnre.diagnostics.mcmc:Target acceptance rate: 0.234
# INFO:abcnre.diagnostics.mcmc:Robbins-Monro tuning with 10000 samples
# INFO:abcnre.diagnostics.mcmc:Target acceptance rate: 0.234
# INFO:abcnre.diagnostics.mcmc:Empirical covariance from 500 preliminary samples
# INFO:abcnre.diagnostics.mcmc:Empirical covariance from 500 preliminary samples
# INFO:abcnre.diagnostics.mcmc:Phase 1/15, scale: 1.0000, acceptance: 0.051, step_size: 1.0000
# INFO:abcnre.diagnostics.mcmc:Phase 1/15, scale: 1.0000, acceptance: 0.051, step_size: 1.0000
# INFO:abcnre.diagnostics.mcmc:Phase 4/15, scale: 0.6724, acceptance: 0.084, step_size: 0.4353
# INFO:abcnre.diagnostics.mcmc:Phase 4/15, scale: 0.6724, acceptance: 0.084, step_size: 0.4353
# INFO:abcnre.diagnostics.mcmc:Phase 7/15, scale: 0.5805, acceptance: 0.138, step_size: 0.3111
# INFO:abcnre.diagnostics.mcmc:Phase 7/15, scale: 0.5805, acceptance: 0.138, step_size: 0.3111
# INFO:abcnre.diagnostics.mcmc:Phase 10/15, scale: 0.5450, acceptance: 0.234, step_size: 0.2512
# INFO:abcnre.diagnostics.mcmc:Phase 10/15, scale: 0.5450, acceptance: 0.234, step_size: 0.2512
# INFO:abcnre.diagnostics.mcmc:Phase 13/15, scale: 0.5387, acceptance: 0.251, step_size: 0.2146
# INFO:abcnre.diagnostics.mcmc:Phase 13/15, scale: 0.5387, acceptance: 0.251, step_size: 0.2146
# INFO:abcnre.diagnostics.mcmc:Robbins-Monro tuning completed. Final scale: 0.5438
# INFO:abcnre.diagnostics.mcmc:Final acceptance rate: 0.264
# INFO:abcnre.diagnostics.mcmc:Robbins-Monro tuning completed. Final scale: 0.5438
# INFO:abcnre.diagnostics.mcmc:Final acceptance rate: 0.264
# INFO:abcnre.diagnostics.mcmc:Running Metropolis-Hastings: 50000 iterations, 50000 final samples, burnin=0, thin=1
# INFO:abcnre.diagnostics.mcmc:Running Metropolis-Hastings: 50000 iterations, 50000 final samples, burnin=0, thin=1
# INFO:abcnre.diagnostics.mcmc:MCMC completed. Final acceptance rate: 0.274
# INFO:abcnre.diagnostics.mcmc:Target acceptance rate: 0.234
# INFO:abcnre.diagnostics.mcmc:MCMC completed. Final acceptance rate: 0.274
# INFO:abcnre.diagnostics.mcmc:Target acceptance rate: 0.234

# %%
plot_mcmc_output(
    mcmc_results=nre_mcmc,
    true_values=true_theta, 
    parameter_names=['A', 'B', 'g', 'k'],
    title="NRE Posterior Estimation - G&K Model",
    figsize=(16, 12)
)

plot_mcmc_output(
    mcmc_results=correct_nre_mcmc,
    true_values=true_theta, 
    parameter_names=['A', 'B', 'g', 'k'],
    title="Corrected NRE Posterior Estimation - G&K Model",
    figsize=(16, 12)
)

plot_mcmc_output(
    mcmc_results=true_mcmc,
    true_values=true_theta, 
    parameter_names=['A', 'B', 'g', 'k'],
    title="True Posterior Estimation - G&K Model",
    figsize=(16, 12)
)

# %%
# Test des nouvelles fonctions de comparaison marginale
from abcnre.diagnostics.viz import plot_1D_marginal_comparison, plot_2D_marginal_comparison


# Préparer les données pour comparaison (seulement MCMC compatible)
samples_comparison = {
    'NRE': nre_mcmc.samples,
    'Corrected NRE': correct_nre_mcmc.samples, 
    'True Posterior': true_mcmc.samples
}


plot_1D_marginal_comparison(
    samples_dict=samples_comparison,
    parameter_names=['A', 'B', 'g', 'k'],
    true_values=true_theta,
    title="Comparison of 1D Marginal Posteriors - G&K Model"
)

plot_2D_marginal_comparison(
    samples_dict=samples_comparison,
    parameter_names=['A', 'B', 'g', 'k'],
    true_values=true_theta,
    title="Comparison of 2D Marginal Posteriors - G&K Model",
    alpha=0.4  
)
# Out:
# /Users/antoineluciano/.pyenv/versions/jax_env/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import jax
from jax import jit
import jax.scipy.stats as jax_stats

@jit
def Q_of_u(u, theta):
    a, b, g, k = theta  # Même convention que Q_of_z
    
    z = jax_stats.norm.ppf(u)
    tanh_term = jnp.tanh(g * z / 2)
    quantile = a + b * (1 + .8 * tanh_term) * jnp.power(1 + z**2, k) * z
    
    return quantile

def get_Q_grids(theta, n_points=1000):
    u_grid = jnp.linspace(1e-6, 1-1e-6, n_points)
    q_grid = Q_of_u(u_grid, theta)
    return u_grid, q_grid

@jit
def pdf_from_cdf_finite_diff(x, u_grid, q_grid, dx=1e-4):
    # S'assurer que x est un scalaire
    x_scalar = jnp.squeeze(x)
    cdf_x_plus = jnp.interp(x_scalar + dx/2, q_grid, u_grid)
    cdf_x_minus = jnp.interp(x_scalar - dx/2, q_grid, u_grid)
    return (cdf_x_plus - cdf_x_minus) / dx

pdf_from_cdf_finite_diff_vectorized = jax.jit(jax.vmap(pdf_from_cdf_finite_diff, in_axes=(0, None, None)))

def lik_from_xobs_grid(x_obs, theta, n_points=1000):

    u_grid, q_grid = get_Q_grids(theta, n_points=n_points)
    pdf_values = pdf_from_cdf_finite_diff_vectorized(x_obs, u_grid, q_grid)
    return jnp.prod(jnp.array(pdf_values))

# %%
import jax
import jax.numpy as jnp
from jax import lax

# Constantes
LOG2PI = jnp.log(2.0 * jnp.pi)

# Fonctions auxiliaires G&K optimisées
@jax.jit
def _A(z, g):
    return 1.0 + 0.8 * jnp.tanh(0.5 * g * z)

@jax.jit
def _dA(z, g):
    u = 0.5 * g * z
    return 0.4 * g * (1.0 / jnp.cosh(u))**2

@jax.jit
def _H(z, k):
    return (1.0 + z**2)**k

@jax.jit
def _dH(z, k):
    return 2.0 * k * z * (1.0 + z**2)**(k - 1.0)

@jax.jit
def Q_of_z(z, theta):
    a, b, g, k = theta
    return a + b * _A(z, g) * _H(z, k) * z

@jax.jit
def dQdz(z, theta):
    a, b, g, k = theta
    A, H = _A(z, g), _H(z, k)
    dA, dH = _dA(z, g), _dH(z, k)
    return b * (A * H + A * z * dH + H * z * dA)

@jax.jit
def solve_z_for_x(x, theta, z_min=-8.0, z_max=8.0, newton_steps=25, bisect_steps=35):
    x_scalar = jnp.squeeze(x)
    
    # Bornes de l'intervalle
    q_lo = Q_of_z(z_min, theta)
    q_hi = Q_of_z(z_max, theta)
    
    # Cas limites
    def _return_low(_): return z_min
    def _return_high(_): return z_max
    
    def _solve(_):
        a, b, g, k = theta
        # Initialisation intelligente
        z0 = jnp.clip((x_scalar - a) / jnp.maximum(jnp.abs(b), 1e-8), z_min, z_max)
        z_lo, z_hi, z = z_min, z_max, z0
        
        # Phase Newton-Raphson avec fallback bissection
        def newton_body(carry, _):
            z_lo, z_hi, z = carry
            f = Q_of_z(z, theta) - x_scalar
            df = dQdz(z, theta)
            
            # Newton step protégé
            z_newton = z - f / jnp.where(jnp.abs(df) < 1e-12, jnp.sign(df) * 1e-12, df)
            z_bis = 0.5 * (z_lo + z_hi)
            
            # Choix du meilleur step
            in_bracket = (z_newton >= z_lo) & (z_newton <= z_hi)
            f_newton = Q_of_z(z_newton, theta) - x_scalar
            f_bis = Q_of_z(z_bis, theta) - x_scalar
            
            use_newton = in_bracket & (jnp.abs(f_newton) <= jnp.abs(f_bis))
            z_next = jnp.where(use_newton, z_newton, z_bis)
            f_next = jnp.where(use_newton, f_newton, f_bis)
            
            # Update brackets
            z_lo = jnp.where(f_next < 0.0, z_next, z_lo)
            z_hi = jnp.where(f_next >= 0.0, z_next, z_hi)
            
            return (z_lo, z_hi, z_next), None
        
        (z_lo, z_hi, z), _ = lax.scan(newton_body, (z_lo, z_hi, z), xs=None, length=newton_steps)
        
        # Raffinement final par bissection
        def bisect_body(carry, _):
            z_lo, z_hi = carry
            z_mid = 0.5 * (z_lo + z_hi)
            f_mid = Q_of_z(z_mid, theta) - x_scalar
            z_lo = jnp.where(f_mid < 0.0, z_mid, z_lo)
            z_hi = jnp.where(f_mid >= 0.0, z_mid, z_hi)
            return (z_lo, z_hi), None
        
        (z_lo, z_hi), _ = lax.scan(bisect_body, (z_lo, z_hi), xs=None, length=bisect_steps)
        return 0.5 * (z_lo + z_hi)
    
    return lax.cond(x_scalar <= q_lo, _return_low,
                    lambda _: lax.cond(x_scalar >= q_hi, _return_high, _solve, operand=None),
                    operand=None)

@jax.jit
def logpdf_gandk(x, theta, eps=1e-12):
    z_star = solve_z_for_x(x, theta)
    
    # Log-PDF = log φ(z) - log |Q'(z)|
    log_phi = -0.5 * z_star**2 - 0.5 * LOG2PI
    qprime = jnp.maximum(jnp.abs(dQdz(z_star, theta)), eps)
    
    return log_phi - jnp.log(qprime)

# Vectorisation pour multiples observations
logpdf_gandk_vectorized = jax.jit(jax.vmap(logpdf_gandk, in_axes=(0, None)))

@jax.jit
def loglikelihood_gandk_newton(x_obs, theta):
    return jnp.sum(logpdf_gandk_vectorized(x_obs, theta))
# Out:
# 🚀 CODE FINAL OPTIMISÉ - MÉTHODE NEWTON G&K
# ================================================
